# %% [markdown]
# ## Obtaining BPE vocabularies

# %% [markdown]
# This notebook has an example of how to obtain a BPE vocabulary of ''musical words''
# from a set of training data (note transcriptions of s manuscript in this case).
#
# The used code can be found inside the directory `src/bpe` and the obtained results will be stored inside `results/test`.

# %% [markdown]
# ------

# %% [markdown]
# For example, for the *Einsiedeln* dataset encoded with *musical* notation.
#
# - Ground Truth = `../data/GT/EIN_music.txt`
#
# - Minimum occurrences (BPE treshold) = `5`
#
# - Maximum token length (BPE treshold) = `5`
#
# - Path for resulting vocabulary = `../results/test/BPE_5-5_vocab.txt`
#
# - Path for resulting encoded data = `../results/test/BPE_5-5_encoded.txt`

# %%
# !python3 ../src/bpe/train_bpe.py \
     -gt "../data/GT/EIN_music.txt" \
     -mo 5 \
     -mxl 5 \
     -v "../results/test/BPE_5-5_vocab.txt" \
     -t "../results/test/BPE_5-5_encoded.txt"
# Out:
# Applying BPE...
# Merge 1: ('A4', 'G4') -> A4&G4 (occurrences: 14393)
# Merge 2: ('F4', 'G4') -> F4&G4 (occurrences: 9576)
# Merge 3: ('C5', 'C5') -> C5&C5 (occurrences: 8440)
# Merge 4: ('F4', 'E4') -> F4&E4 (occurrences: 6601)
# Merge 5: ('C5', 'B4') -> C5&B4 (occurrences: 4872)
# Merge 6: ('C5', 'D5') -> C5&D5 (occurrences: 4762)
# Merge 7: ('A4', 'A4') -> A4&A4 (occurrences: 3704)
# Merge 8: ('D4', 'D4') -> D4&D4 (occurrences: 3696)
# Merge 9: ('G4', 'G4') -> G4&G4 (occurrences: 3367)
# Merge 10: ('A4&G4', 'A4') -> A4&G4&A4 (occurrences: 2982)
# Merge 11: ('F4', 'F4') -> F4&F4 (occurrences: 2864)
# Merge 12: ('E5', 'D5') -> E5&D5 (occurrences: 2578)
# Merge 13: ('F4&E4', 'D4') -> F4&E4&D4 (occurrences: 2490)
# Merge 14: ('A4&G4', 'F4&G4') -> A4&G4&F4&G4 (occurrences: 2339)
# Merge 15: ('A4&G4', 'G4') -> A4&G4&G4 (occurrences: 2243)
# Merge 16: ('A4', 'B4') -> A4&B4 (occurrences: 2207)
# Merge 17: ('C4', 'D4') -> C4&D4 (occurrences: 2027)
# Merge 18: ('A4', 'C5') -> A4&C5 (occurrences: 1874)
# Merge 19: ('F4', 'D4') -> F4&D4 (occurrences: 1853)
# Merge 20: ('C5&C5', 'B4') -> C5&C5&B4 (occurrences: 1782)
# Merge 21: ('D5', 'D5') -> D5&D5 (occurrences: 1661)
# Merge 22: ('E4', 'F4&G4') -> E4&F4&G4 (occurrences: 1057)
# Merge 23: ('F4&E4', 'F4&G4') -> F4&E4&F4&G4 (occurrences: 1040)
# Merge 24: ('C5', 'A4') -> C5&A4 (occurrences: 1021)
# Merge 25: ('F4', 'F4&G4') -> F4&F4&G4 (occurrences: 990)
# Merge 26: ('C5&C5', 'C5&C5') -> C5&C5&C5&C5 (occurrences: 964)
# Merge 27: ('A4&G4', 'A4&G4') -> A4&G4&A4&G4 (occurrences: 871)
# Merge 28: ('E5', 'F5') -> E5&F5 (occurrences: 869)
# Merge 29: ('G4', 'A4') -> G4&A4 (occurrences: 837)
# Merge 30: ('F4', 'D4&D4') -> F4&D4&D4 (occurrences: 832)
# Merge 31: ('C5&C5', 'D5') -> C5&C5&D5 (occurrences: 828)
# Merge 32: ('C4', 'D4&D4') -> C4&D4&D4 (occurrences: 820)
# Merge 33: ('C5&D5', 'C5&B4') -> C5&D5&C5&B4 (occurrences: 808)
# Merge 34: ('F4&E4', 'D4&D4') -> F4&E4&D4&D4 (occurrences: 735)
# Merge 35: ('A4&G4&A4', 'B4') -> A4&G4&A4&B4 (occurrences: 716)
# Merge 36: ('A4&G4', 'G4&G4') -> A4&G4&G4&G4 (occurrences: 694)
# Merge 37: ('F4&E4&D4', 'E4') -> F4&E4&D4&E4 (occurrences: 674)
# Merge 38: ('A4&G4&A4', 'C5') -> A4&G4&A4&C5 (occurrences: 638)
# Merge 39: ('A4&B4', 'C5&B4') -> A4&B4&C5&B4 (occurrences: 632)
# Merge 40: ('C5&D5', 'D5') -> C5&D5&D5 (occurrences: 629)
# Merge 41: ('F4&G4', 'A4') -> F4&G4&A4 (occurrences: 578)
# Merge 42: ('C5&D5', 'E5&D5') -> C5&D5&E5&D5 (occurrences: 533)
# Merge 43: ('C5', 'A4&G4') -> C5&A4&G4 (occurrences: 519)
# Merge 44: ('F4', 'A4') -> F4&A4 (occurrences: 512)
# Merge 45: ('F4', 'F4&E4') -> F4&F4&E4 (occurrences: 479)
# Merge 46: ('F4&G4', 'A4&G4') -> F4&G4&A4&G4 (occurrences: 471)
# Merge 47: ('G4', 'A4&G4') -> G4&A4&G4 (occurrences: 461)
# Merge 48: ('A4', 'A4&G4') -> A4&A4&G4 (occurrences: 434)
# Merge 49: ('E4', 'E4') -> E4&E4 (occurrences: 416)
# Merge 50: ('A4', 'C5&B4') -> A4&C5&B4 (occurrences: 404)
# Merge 51: ('E5&D5', 'C5&B4') -> E5&D5&C5&B4 (occurrences: 404)
# Merge 52: ('C5&C5', 'C5&B4') -> C5&C5&C5&B4 (occurrences: 386)
# Merge 53: ('F4&G4', 'G4') -> F4&G4&G4 (occurrences: 381)
# Merge 54: ('F4&G4', 'A4&A4') -> F4&G4&A4&A4 (occurrences: 358)
# Merge 55: ('E5&F5', 'E5&D5') -> E5&F5&E5&D5 (occurrences: 355)
# Merge 56: ('F4&F4', 'D4') -> F4&F4&D4 (occurrences: 349)
# Merge 57: ('C5&D5', 'C5&C5&B4') -> C5&D5&C5&C5&B4 (occurrences: 340)
# Merge 58: ('F4&E4&D4', 'C4&D4') -> F4&E4&D4&C4&D4 (occurrences: 339)
# Merge 59: ('A4&G4&F4&G4', 'A4') -> A4&G4&F4&G4&A4 (occurrences: 338)
# Merge 60: ('A4&G4&F4&G4', 'G4') -> A4&G4&F4&G4&G4 (occurrences: 325)
# Merge 61: ('A4&G4&A4', 'A4&G4') -> A4&G4&A4&A4&G4 (occurrences: 323)
# Merge 62: ('E4', 'D4') -> E4&D4 (occurrences: 312)
# Merge 63: ('G4', 'E4') -> G4&E4 (occurrences: 298)
# Merge 64: ('C5&D5', 'D5&D5') -> C5&D5&D5&D5 (occurrences: 287)
# Merge 65: ('G4', 'A4&C5') -> G4&A4&C5 (occurrences: 284)
# Merge 66: ('F4&F4', 'F4&F4') -> F4&F4&F4&F4 (occurrences: 283)
# Merge 67: ('C5', 'A4&C5') -> C5&A4&C5 (occurrences: 281)
# Merge 68: ('E4', 'F4&D4') -> E4&F4&D4 (occurrences: 269)
# Merge 69: ('C5&D5', 'C5&C5') -> C5&D5&C5&C5 (occurrences: 258)
# Merge 70: ('G5', 'F5') -> G5&F5 (occurrences: 258)
# Merge 71: ('A4&A4', 'A4&A4') -> A4&A4&A4&A4 (occurrences: 252)
# Merge 72: ('D5', 'E5&D5') -> D5&E5&D5 (occurrences: 250)
# Merge 73: ('A4&G4&G4', 'F4&G4') -> A4&G4&G4&F4&G4 (occurrences: 249)
# Merge 74: ('A4', 'A4&G4&F4&G4') -> A4&A4&G4&F4&G4 (occurrences: 244)
# Merge 75: ('C4', 'F4&G4') -> C4&F4&G4 (occurrences: 244)
# Merge 76: ('D5', 'B4') -> D5&B4 (occurrences: 244)
# Merge 77: ('A4&A4', 'C5') -> A4&A4&C5 (occurrences: 231)
# Merge 78: ('G4&G4', 'G4') -> G4&G4&G4 (occurrences: 231)
# Merge 79: ('C4', 'C4&D4') -> C4&C4&D4 (occurrences: 225)
# Merge 80: ('A4&A4', 'B4') -> A4&A4&B4 (occurrences: 221)
# Merge 81: ('C5&D5', 'B4') -> C5&D5&B4 (occurrences: 218)
# Merge 82: ('C5&D5', 'F5') -> C5&D5&F5 (occurrences: 217)
# Merge 83: ('F4', 'F4&E4&D4') -> F4&F4&E4&D4 (occurrences: 215)
# Merge 84: ('E5', 'E5&D5') -> E5&E5&D5 (occurrences: 210)
# Merge 85: ('F4&E4', 'F4&D4') -> F4&E4&F4&D4 (occurrences: 208)
# Merge 86: ('A4&G4&G4', 'A4&C5') -> A4&G4&G4&A4&C5 (occurrences: 206)
# Merge 87: ('C5&D5', 'C5') -> C5&D5&C5 (occurrences: 203)
# Merge 88: ('F4', 'F4&E4&F4&G4') -> F4&F4&E4&F4&G4 (occurrences: 199)
# Merge 89: ('D4', 'C4&D4') -> D4&C4&D4 (occurrences: 198)
# Merge 90: ('A4', 'C5&C5') -> A4&C5&C5 (occurrences: 191)
# Merge 91: ('F4&E4', 'E4') -> F4&E4&E4 (occurrences: 181)
# Merge 92: ('F4&D4', 'C4&D4') -> F4&D4&C4&D4 (occurrences: 176)
# Merge 93: ('F4&E4', 'F4&E4&D4') -> F4&E4&F4&E4&D4 (occurrences: 176)
# Merge 94: ('G4', 'A4&G4&G4') -> G4&A4&G4&G4 (occurrences: 174)
# Merge 95: ('F4', 'C4&D4') -> F4&C4&D4 (occurrences: 173)
# Merge 96: ('D5', 'C5&B4') -> D5&C5&B4 (occurrences: 171)
# Merge 97: ('A4&G4&A4', 'C5&B4') -> A4&G4&A4&C5&B4 (occurrences: 170)
# Merge 98: ('C4', 'C4') -> C4&C4 (occurrences: 169)
# Merge 99: ('G4', 'A4&B4') -> G4&A4&B4 (occurrences: 169)
# Merge 100: ('E4', 'F4&E4&D4') -> E4&F4&E4&D4 (occurrences: 168)
# Merge 101: ('A4&B4', 'A4&G4') -> A4&B4&A4&G4 (occurrences: 164)
# Merge 102: ('G4', 'B4') -> G4&B4 (occurrences: 163)
# Merge 103: ('E4', 'F4&E4&D4&E4') -> E4&F4&E4&D4&E4 (occurrences: 161)
# Merge 104: ('A4', 'A4&G4&G4') -> A4&A4&G4&G4 (occurrences: 159)
# Merge 105: ('A4', 'C5&C5&B4') -> A4&C5&C5&B4 (occurrences: 159)
# Merge 106: ('G4&G4', 'G4&G4') -> G4&G4&G4&G4 (occurrences: 155)
# Merge 107: ('F4&F4', 'F4&G4') -> F4&F4&F4&G4 (occurrences: 153)
# Merge 108: ('C4&D4&D4', 'D4') -> C4&D4&D4&D4 (occurrences: 150)
# Merge 109: ('C5&D5', 'C5&C5&D5') -> C5&D5&C5&C5&D5 (occurrences: 150)
# Merge 110: ('E4', 'F4&D4&D4') -> E4&F4&D4&D4 (occurrences: 148)
# Merge 111: ('E4&F4&G4', 'G4') -> E4&F4&G4&G4 (occurrences: 148)
# Merge 112: ('C5&D5', 'C5&D5&D5') -> C5&D5&C5&D5&D5 (occurrences: 145)
# Merge 113: ('A4&A4', 'A4') -> A4&A4&A4 (occurrences: 144)
# Merge 114: ('F4', 'F4&E4&D4&E4') -> F4&F4&E4&D4&E4 (occurrences: 144)
# Merge 115: ('F4&E4', 'C4&D4') -> F4&E4&C4&D4 (occurrences: 143)
# Merge 116: ('A4&B4', 'C5') -> A4&B4&C5 (occurrences: 138)
# Merge 117: ('C5&B4', 'A4&G4') -> C5&B4&A4&G4 (occurrences: 135)
# Merge 118: ('G4', 'F4&G4') -> G4&F4&G4 (occurrences: 133)
# Merge 119: ('B4', 'B4') -> B4&B4 (occurrences: 132)
# Merge 120: ('C5&C5', 'C5') -> C5&C5&C5 (occurrences: 130)
# Merge 121: ('C5&D5', 'E5') -> C5&D5&E5 (occurrences: 128)
# Merge 122: ('C5&B4', 'A4') -> C5&B4&A4 (occurrences: 127)
# Merge 123: ('C5&C5&B4', 'C5&A4') -> C5&C5&B4&C5&A4 (occurrences: 122)
# Merge 124: ('D5&D5', 'D5&D5') -> D5&D5&D5&D5 (occurrences: 121)
# Merge 125: ('D5', 'F5') -> D5&F5 (occurrences: 119)
# Merge 126: ('E4', 'F4&E4') -> E4&F4&E4 (occurrences: 119)
# Merge 127: ('A4', 'F4&G4') -> A4&F4&G4 (occurrences: 118)
# Merge 128: ('F4', 'A4&G4') -> F4&A4&G4 (occurrences: 117)
# Merge 129: ('A4&C5', 'A4') -> A4&C5&A4 (occurrences: 114)
# Merge 130: ('G5&F5', 'E5&D5') -> G5&F5&E5&D5 (occurrences: 113)
# Merge 131: ('A4&A4', 'A4&G4') -> A4&A4&A4&G4 (occurrences: 112)
# Merge 132: ('A4&G4&A4', 'F4&G4') -> A4&G4&A4&F4&G4 (occurrences: 111)
# Merge 133: ('C5&C5&B4', 'C5') -> C5&C5&B4&C5 (occurrences: 109)
# Merge 134: ('G4&A4', 'C5&B4') -> G4&A4&C5&B4 (occurrences: 109)
# Merge 135: ('G4', 'A4&G4&F4&G4') -> G4&A4&G4&F4&G4 (occurrences: 107)
# Merge 136: ('A4&C5', 'A4&A4') -> A4&C5&A4&A4 (occurrences: 105)
# Merge 137: ('F4&D4', 'C4&D4&D4') -> F4&D4&C4&D4&D4 (occurrences: 103)
# Merge 138: ('F4&D4&D4', 'D4') -> F4&D4&D4&D4 (occurrences: 102)
# Merge 139: ('C5&C5', 'C5&C5&B4') -> C5&C5&C5&C5&B4 (occurrences: 100)
# Merge 140: ('D4&D4', 'D4') -> D4&D4&D4 (occurrences: 100)
# Merge 141: ('D5', 'C5&D5&F5') -> D5&C5&D5&F5 (occurrences: 99)
# Merge 142: ('A4&G4&G4', 'A4&G4') -> A4&G4&G4&A4&G4 (occurrences: 98)
# Merge 143: ('C5&C5&D5', 'B4') -> C5&C5&D5&B4 (occurrences: 98)
# Merge 144: ('F4', 'A4&C5') -> F4&A4&C5 (occurrences: 98)
# Merge 145: ('A4&A4', 'C5&B4') -> A4&A4&C5&B4 (occurrences: 95)
# Merge 146: ('A4&B4', 'B4') -> A4&B4&B4 (occurrences: 95)
# Merge 147: ('D5&D5', 'E5&D5') -> D5&D5&E5&D5 (occurrences: 95)
# Merge 148: ('C5&B4', 'C5&B4') -> C5&B4&C5&B4 (occurrences: 92)
# Merge 149: ('F4&E4', 'G4&G4') -> F4&E4&G4&G4 (occurrences: 92)
# Merge 150: ('F5', 'F5') -> F5&F5 (occurrences: 92)
# Merge 151: ('E4&F4&G4', 'G4&G4') -> E4&F4&G4&G4&G4 (occurrences: 91)
# Merge 152: ('A4&G4&G4', 'A4') -> A4&G4&G4&A4 (occurrences: 89)
# Merge 153: ('C5', 'A4&B4') -> C5&A4&B4 (occurrences: 88)
# Merge 154: ('A4&G4&A4&B4', 'A4') -> A4&G4&A4&B4&A4 (occurrences: 87)
# Merge 155: ('E4', 'F4&E4&D4&D4') -> E4&F4&E4&D4&D4 (occurrences: 87)
# Merge 156: ('F4&D4', 'C4') -> F4&D4&C4 (occurrences: 87)
# Merge 157: ('E5&F5', 'G5') -> E5&F5&G5 (occurrences: 86)
# Merge 158: ('C5&A4', 'A4&G4&A4') -> C5&A4&A4&G4&A4 (occurrences: 85)
# Merge 159: ('D5', 'E5') -> D5&E5 (occurrences: 85)
# Merge 160: ('F4', 'F4&E4&D4&D4') -> F4&F4&E4&D4&D4 (occurrences: 84)
# Merge 161: ('C5&C5', 'C5&A4') -> C5&C5&C5&A4 (occurrences: 83)
# Merge 162: ('E4', 'G4') -> E4&G4 (occurrences: 83)
# Merge 163: ('F4&F4&G4', 'A4&G4') -> F4&F4&G4&A4&G4 (occurrences: 83)
# Merge 164: ('C5&C5&D5', 'C5&C5') -> C5&C5&D5&C5&C5 (occurrences: 82)
# Merge 165: ('D4', 'C4') -> D4&C4 (occurrences: 81)
# Merge 166: ('F4&F4&G4', 'A4') -> F4&F4&G4&A4 (occurrences: 81)
# Merge 167: ('F4&E4&F4&G4', 'G4') -> F4&E4&F4&G4&G4 (occurrences: 80)
# Merge 168: ('E4', 'G4&E4') -> E4&G4&E4 (occurrences: 79)
# Merge 169: ('C5&A4', 'A4&G4') -> C5&A4&A4&G4 (occurrences: 78)
# Merge 170: ('G5', 'A5') -> G5&A5 (occurrences: 78)
# Merge 171: ('A4&A4', 'A4&G4&G4') -> A4&A4&A4&G4&G4 (occurrences: 77)
# Merge 172: ('A4&C5', 'A4&G4') -> A4&C5&A4&G4 (occurrences: 77)
# Merge 173: ('G4&A4', 'C5&C5') -> G4&A4&C5&C5 (occurrences: 77)
# Merge 174: ('D5', 'E5&F5&E5&D5') -> D5&E5&F5&E5&D5 (occurrences: 76)
# Merge 175: ('A4&G4', 'F4&E4&D4') -> A4&G4&F4&E4&D4 (occurrences: 75)
# Merge 176: ('C5&C5&C5&C5', 'D5') -> C5&C5&C5&C5&D5 (occurrences: 75)
# Merge 177: ('E5&F5', 'D5') -> E5&F5&D5 (occurrences: 75)
# Merge 178: ('F4&D4', 'F4&F4') -> F4&D4&F4&F4 (occurrences: 75)
# Merge 179: ('A4', 'D5&B4') -> A4&D5&B4 (occurrences: 72)
# Merge 180: ('F4&G4', 'F4&E4') -> F4&G4&F4&E4 (occurrences: 72)
# Merge 181: ('A4&C5', 'G4&A4&G4') -> A4&C5&G4&A4&G4 (occurrences: 71)
# Merge 182: ('A4&G4&G4', 'D5&D5') -> A4&G4&G4&D5&D5 (occurrences: 71)
# Merge 183: ('A4&G4&G4&G4', 'G4') -> A4&G4&G4&G4&G4 (occurrences: 71)
# Merge 184: ('C5&B4', 'B4') -> C5&B4&B4 (occurrences: 70)
# Merge 185: ('D5&D5', 'B4') -> D5&D5&B4 (occurrences: 70)
# Merge 186: ('A3', 'C4&D4') -> A3&C4&D4 (occurrences: 69)
# Merge 187: ('C5&B4', 'A4&B4') -> C5&B4&A4&B4 (occurrences: 68)
# Merge 188: ('C5&B4', 'C5') -> C5&B4&C5 (occurrences: 67)
# Merge 189: ('C5&D5', 'C5&A4') -> C5&D5&C5&A4 (occurrences: 67)
# Merge 190: ('F4&F4', 'F4&E4') -> F4&F4&F4&E4 (occurrences: 67)
# Merge 191: ('F4&G4', 'F4&G4') -> F4&G4&F4&G4 (occurrences: 67)
# Merge 192: ('F4&A4', 'C5&C5') -> F4&A4&C5&C5 (occurrences: 66)
# Merge 193: ('F4&D4', 'E4&F4&G4') -> F4&D4&E4&F4&G4 (occurrences: 66)
# Merge 194: ('F4&F4&E4', 'F4&D4') -> F4&F4&E4&F4&D4 (occurrences: 66)
# Merge 195: ('F4&G4&A4', 'A4&G4') -> F4&G4&A4&A4&G4 (occurrences: 66)
# Merge 196: ('A4&G4&A4&C5', 'G4') -> A4&G4&A4&C5&G4 (occurrences: 65)
# Merge 197: ('C4&D4', 'F4&F4') -> C4&D4&F4&F4 (occurrences: 64)
# Merge 198: ('C5&C5&B4', 'A4&G4') -> C5&C5&B4&A4&G4 (occurrences: 64)
# Merge 199: ('F4&E4&D4&D4', 'D4') -> F4&E4&D4&D4&D4 (occurrences: 64)
# Merge 200: ('F4&G4', 'A4&G4&G4') -> F4&G4&A4&G4&G4 (occurrences: 64)
# Merge 201: ('G4&G4', 'A4') -> G4&G4&A4 (occurrences: 64)
# Merge 202: ('F4&F4', 'A4') -> F4&F4&A4 (occurrences: 63)
# Merge 203: ('G4&A4&B4', 'A4') -> G4&A4&B4&A4 (occurrences: 63)
# Merge 204: ('E5&D5&C5&B4', 'A4') -> E5&D5&C5&B4&A4 (occurrences: 62)
# Merge 205: ('F4&E4&D4&E4', 'E4') -> F4&E4&D4&E4&E4 (occurrences: 62)
# Merge 206: ('F5', 'E5&D5') -> F5&E5&D5 (occurrences: 62)
# Merge 207: ('A4&B4', 'C5&A4&C5') -> A4&B4&C5&A4&C5 (occurrences: 61)
# Merge 208: ('F4', 'A4&A4') -> F4&A4&A4 (occurrences: 61)
# Merge 209: ('F4&G4&A4&G4', 'F4') -> F4&G4&A4&G4&F4 (occurrences: 60)
# Merge 210: ('A4&G4', 'F4&E4') -> A4&G4&F4&E4 (occurrences: 59)
# Merge 211: ('F4&D4&D4', 'C4') -> F4&D4&D4&C4 (occurrences: 59)
# Merge 212: ('E5&F5', 'E5&E5&D5') -> E5&F5&E5&E5&D5 (occurrences: 58)
# Merge 213: ('C4&D4&D4', 'D4&D4') -> C4&D4&D4&D4&D4 (occurrences: 57)
# Merge 214: ('F4&A4', 'C5&C5&B4') -> F4&A4&C5&C5&B4 (occurrences: 57)
# Merge 215: ('G4&G4', 'D5&D5') -> G4&G4&D5&D5 (occurrences: 57)
# Merge 216: ('A4&A4&G4', 'F4&E4') -> A4&A4&G4&F4&E4 (occurrences: 56)
# Merge 217: ('A4&B4', 'A4&G4&G4') -> A4&B4&A4&G4&G4 (occurrences: 56)
# Merge 218: ('A4&G4&A4', 'C5&A4') -> A4&G4&A4&C5&A4 (occurrences: 56)
# Merge 219: ('G4', 'F4&F4') -> G4&F4&F4 (occurrences: 56)
# Merge 220: ('B4', 'C5') -> B4&C5 (occurrences: 54)
# Merge 221: ('C4&D4', 'F4&G4') -> C4&D4&F4&G4 (occurrences: 54)
# Merge 222: ('C5&B4', 'C5&D5&D5') -> C5&B4&C5&D5&D5 (occurrences: 54)
# Merge 223: ('C5&C5', 'A4') -> C5&C5&A4 (occurrences: 54)
# Merge 224: ('A4&C5', 'G4&G4') -> A4&C5&G4&G4 (occurrences: 53)
# Merge 225: ('C5&C5&D5', 'E5&D5') -> C5&C5&D5&E5&D5 (occurrences: 53)
# Merge 226: ('C5&B4', 'C5&D5') -> C5&B4&C5&D5 (occurrences: 52)
# Merge 227: ('D5', 'E5&F5') -> D5&E5&F5 (occurrences: 52)
# Merge 228: ('D5', 'C5&D5') -> D5&C5&D5 (occurrences: 51)
# Merge 229: ('E4', 'G4&A4&G4') -> E4&G4&A4&G4 (occurrences: 51)
# Merge 230: ('F4&F4&G4', 'F4&F4') -> F4&F4&G4&F4&F4 (occurrences: 51)
# Merge 231: ('A4&A4', 'C5&A4&G4') -> A4&A4&C5&A4&G4 (occurrences: 50)
# Merge 232: ('E4', 'G4&A4') -> E4&G4&A4 (occurrences: 50)
# Merge 233: ('F4&E4&D4', 'C4') -> F4&E4&D4&C4 (occurrences: 49)
# Merge 234: ('G4&G4', 'A4&G4') -> G4&G4&A4&G4 (occurrences: 49)
# Merge 235: ('A4&A4', 'F4&G4') -> A4&A4&F4&G4 (occurrences: 48)
# Merge 236: ('B4', 'C5&D5&C5&B4') -> B4&C5&D5&C5&B4 (occurrences: 48)
# Merge 237: ('C5', 'G4') -> C5&G4 (occurrences: 48)
# Merge 238: ('D4', 'E4&F4&G4') -> D4&E4&F4&G4 (occurrences: 48)
# Merge 239: ('D4&D4', 'C4&F4&G4') -> D4&D4&C4&F4&G4 (occurrences: 48)
# Merge 240: ('F4', 'C4') -> F4&C4 (occurrences: 48)
# Merge 241: ('F4&F4', 'A4&A4') -> F4&F4&A4&A4 (occurrences: 48)
# Merge 242: ('B4', 'C5&D5') -> B4&C5&D5 (occurrences: 47)
# Merge 243: ('D4&D4', 'C4') -> D4&D4&C4 (occurrences: 47)
# Merge 244: ('E4&F4&D4', 'C4&D4') -> E4&F4&D4&C4&D4 (occurrences: 47)
# Merge 245: ('F4', 'A4&B4') -> F4&A4&B4 (occurrences: 47)
# Merge 246: ('D5', 'C5&D5&E5&D5') -> D5&C5&D5&E5&D5 (occurrences: 46)
# Merge 247: ('C5&C5&D5', 'C5&B4') -> C5&C5&D5&C5&B4 (occurrences: 45)
# Merge 248: ('E5', 'E5') -> E5&E5 (occurrences: 45)
# Merge 249: ('E5&D5&C5&B4', 'C5') -> E5&D5&C5&B4&C5 (occurrences: 45)
# Merge 250: ('F4', 'A4&G4&G4') -> F4&A4&G4&G4 (occurrences: 45)
# Merge 251: ('F4&D4&D4', 'C4&D4') -> F4&D4&D4&C4&D4 (occurrences: 45)
# Merge 252: ('F4&F4', 'F4&D4') -> F4&F4&F4&D4 (occurrences: 45)
# Merge 253: ('F4&F4&E4', 'G4') -> F4&F4&E4&G4 (occurrences: 45)
# Merge 254: ('A4&G4', 'A4&G4&G4') -> A4&G4&A4&G4&G4 (occurrences: 44)
# Merge 255: ('C5', 'G4&A4') -> C5&G4&A4 (occurrences: 44)
# Merge 256: ('C5&D5&C5&C5', 'A4') -> C5&D5&C5&C5&A4 (occurrences: 44)
# Merge 257: ('E5', 'G5') -> E5&G5 (occurrences: 44)
# Merge 258: ('A4&G4&A4', 'C5&C5') -> A4&G4&A4&C5&C5 (occurrences: 43)
# Merge 259: ('B4', 'C5&D5&D5') -> B4&C5&D5&D5 (occurrences: 43)
# Merge 260: ('F4&F4', 'F4&E4&D4') -> F4&F4&F4&E4&D4 (occurrences: 43)
# Merge 261: ('F4', 'A4&G4&F4&G4') -> F4&A4&G4&F4&G4 (occurrences: 42)
# Merge 262: ('F4&F4&D4', 'F4&D4') -> F4&F4&D4&F4&D4 (occurrences: 42)
# Merge 263: ('C5', 'A4&A4') -> C5&A4&A4 (occurrences: 41)
# Merge 264: ('D5&B4', 'D5&E5&D5') -> D5&B4&D5&E5&D5 (occurrences: 41)
# Merge 265: ('F4&A4', 'C5&B4') -> F4&A4&C5&B4 (occurrences: 41)
# Merge 266: ('A4&G4', 'F4&F4&G4') -> A4&G4&F4&F4&G4 (occurrences: 40)
# Merge 267: ('C4&D4', 'F4&F4&G4') -> C4&D4&F4&F4&G4 (occurrences: 40)
# Merge 268: ('D4', 'F4&G4') -> D4&F4&G4 (occurrences: 40)
# Merge 269: ('F4&D4', 'F4&G4') -> F4&D4&F4&G4 (occurrences: 40)
# Merge 270: ('F4&E4&F4&G4', 'A4') -> F4&E4&F4&G4&A4 (occurrences: 40)
# Merge 271: ('G4', 'F4&G4&G4') -> G4&F4&G4&G4 (occurrences: 40)
# Merge 272: ('G4&G4', 'F4&G4') -> G4&G4&F4&G4 (occurrences: 40)
# Merge 273: ('A4&G4', 'A4&A4') -> A4&G4&A4&A4 (occurrences: 39)
# Merge 274: ('C5&D5&B4', 'C5') -> C5&D5&B4&C5 (occurrences: 39)
# Merge 275: ('F4&E4', 'C4') -> F4&E4&C4 (occurrences: 39)
# Merge 276: ('F4&F4', 'F4&F4&G4') -> F4&F4&F4&F4&G4 (occurrences: 39)
# Merge 277: ('C5&A4', 'C5&C5') -> C5&A4&C5&C5 (occurrences: 38)
# Merge 278: ('D4&D4', 'C4&D4') -> D4&D4&C4&D4 (occurrences: 38)
# Merge 279: ('D5', 'C5&C5&C5&B4') -> D5&C5&C5&C5&B4 (occurrences: 38)
# Merge 280: ('A4&G4', 'B4') -> A4&G4&B4 (occurrences: 37)
# Merge 281: ('C5&C5&B4', 'C5&B4') -> C5&C5&B4&C5&B4 (occurrences: 37)
# Merge 282: ('D4', 'E4&D4') -> D4&E4&D4 (occurrences: 37)
# Merge 283: ('A4&B4', 'A4') -> A4&B4&A4 (occurrences: 36)
# Merge 284: ('A4&B4', 'G4') -> A4&B4&G4 (occurrences: 36)
# Merge 285: ('D5&E5&D5', 'E5&D5') -> D5&E5&D5&E5&D5 (occurrences: 36)
# Merge 286: ('E4&F4&G4', 'F4&G4') -> E4&F4&G4&F4&G4 (occurrences: 36)
# Merge 287: ('F4&E4', 'G4') -> F4&E4&G4 (occurrences: 36)
# Merge 288: ('F4&E4&D4', 'F4&G4') -> F4&E4&D4&F4&G4 (occurrences: 36)
# Merge 289: ('B4', 'C5&B4') -> B4&C5&B4 (occurrences: 35)
# Merge 290: ('C5', '') -> C5& (occurrences: 35)
# Merge 291: ('C5&A4', 'C5&B4') -> C5&A4&C5&B4 (occurrences: 35)
# Merge 292: ('F4&E4', 'F4&D4&D4') -> F4&E4&F4&D4&D4 (occurrences: 35)
# Merge 293: ('A3', 'C4&D4&D4') -> A3&C4&D4&D4 (occurrences: 34)
# Merge 294: ('A4&C5', 'A4&A4&G4') -> A4&C5&A4&A4&G4 (occurrences: 34)
# Merge 295: ('A4&G4', 'E4&F4&G4') -> A4&G4&E4&F4&G4 (occurrences: 34)
# Merge 296: ('C4', 'B3') -> C4&B3 (occurrences: 34)
# Merge 297: ('C5&C5&B4', 'A4') -> C5&C5&B4&A4 (occurrences: 34)
# Merge 298: ('D5', 'C5&C5') -> D5&C5&C5 (occurrences: 34)
# Merge 299: ('E4&E4', 'E4') -> E4&E4&E4 (occurrences: 34)
# Merge 300: ('E5&D5', 'E5&D5') -> E5&D5&E5&D5 (occurrences: 34)
# Merge 301: ('F4', 'A4&A4&B4') -> F4&A4&A4&B4 (occurrences: 34)
# Merge 302: ('G5', 'G5') -> G5&G5 (occurrences: 34)
# Merge 303: ('C4&C4&D4', 'F4&G4') -> C4&C4&D4&F4&G4 (occurrences: 33)
# Merge 304: ('F4&E4', 'C4&D4&D4') -> F4&E4&C4&D4&D4 (occurrences: 33)
# Merge 305: ('F4&F4&G4', 'F4&G4') -> F4&F4&G4&F4&G4 (occurrences: 33)
# Merge 306: ('F4&G4&A4', 'C5&B4') -> F4&G4&A4&C5&B4 (occurrences: 32)
# Merge 307: ('G4', 'A4&G4&G4&G4') -> G4&A4&G4&G4&G4 (occurrences: 32)
# Merge 308: ('G4&G4', 'A4&C5') -> G4&G4&A4&C5 (occurrences: 32)
# Merge 309: ('C4&D4', 'F4&D4') -> C4&D4&F4&D4 (occurrences: 31)
# Merge 310: ('C5&C5', 'C5&A4&C5') -> C5&C5&C5&A4&C5 (occurrences: 31)
# Merge 311: ('C5&C5', 'C5&D5') -> C5&C5&C5&D5 (occurrences: 31)
# Merge 312: ('D5', 'C5&D5&D5') -> D5&C5&D5&D5 (occurrences: 31)
# Merge 313: ('F4&F4', 'F4') -> F4&F4&F4 (occurrences: 31)
# Merge 314: ('F4&G4&A4&A4', 'B4') -> F4&G4&A4&A4&B4 (occurrences: 31)
# Merge 315: ('A4&C5', 'G4') -> A4&C5&G4 (occurrences: 30)
# Merge 316: ('C5&C5', 'D5&D5') -> C5&C5&D5&D5 (occurrences: 30)
# Merge 317: ('E5', 'C5&D5&D5') -> E5&C5&D5&D5 (occurrences: 30)
# Merge 318: ('E5&F5', 'D5&D5') -> E5&F5&D5&D5 (occurrences: 30)
# Merge 319: ('F4', 'C4&D4&D4') -> F4&C4&D4&D4 (occurrences: 30)
# Merge 320: ('F4&E4', 'E4&D4') -> F4&E4&E4&D4 (occurrences: 30)
# Merge 321: ('F4&E4&E4', 'D4&D4') -> F4&E4&E4&D4&D4 (occurrences: 30)
# Merge 322: ('F4&G4&G4', 'F4&G4') -> F4&G4&G4&F4&G4 (occurrences: 30)
# Merge 323: ('G4', 'A4&B4&C5&B4') -> G4&A4&B4&C5&B4 (occurrences: 30)
# Merge 324: ('G4&A4', 'A4&G4&G4') -> G4&A4&A4&G4&G4 (occurrences: 30)
# Merge 325: ('G4&G4', 'B4') -> G4&G4&B4 (occurrences: 30)
# Merge 326: ('A4&G4&G4&G4', 'A4') -> A4&G4&G4&G4&A4 (occurrences: 29)
# Merge 327: ('C5&A4', 'A4&G4&G4') -> C5&A4&A4&G4&G4 (occurrences: 29)
# Merge 328: ('D5', 'C5') -> D5&C5 (occurrences: 29)
# Merge 329: ('G4&G4', 'A4&C5&B4') -> G4&G4&A4&C5&B4 (occurrences: 29)
# Merge 330: ('G4&G4', 'A4&G4&G4') -> G4&G4&A4&G4&G4 (occurrences: 29)
# Merge 331: ('C5&C5', 'G4&B4') -> C5&C5&G4&B4 (occurrences: 28)
# Merge 332: ('D4', 'F4&D4') -> D4&F4&D4 (occurrences: 28)
# Merge 333: ('E4', 'D4&D4') -> E4&D4&D4 (occurrences: 28)
# Merge 334: ('F4&E4&D4', 'F4&D4') -> F4&E4&D4&F4&D4 (occurrences: 28)
# Merge 335: ('F4&F4&D4', 'F4&G4') -> F4&F4&D4&F4&G4 (occurrences: 28)
# Merge 336: ('G4&A4', 'F4&G4') -> G4&A4&F4&G4 (occurrences: 28)
# Merge 337: ('G4&G4', 'G4&G4&G4') -> G4&G4&G4&G4&G4 (occurrences: 28)
# Merge 338: ('C5', 'A4&G4&F4&G4') -> C5&A4&G4&F4&G4 (occurrences: 27)
# Merge 339: ('C5&D5&E5&D5', 'D5') -> C5&D5&E5&D5&D5 (occurrences: 27)
# Merge 340: ('D4', 'F4&E4') -> D4&F4&E4 (occurrences: 27)
# Merge 341: ('F4&F4', 'D4&D4') -> F4&F4&D4&D4 (occurrences: 27)
# Merge 342: ('G4', 'A4&A4') -> G4&A4&A4 (occurrences: 27)
# Merge 343: ('A4', 'A4&G4&A4&C5') -> A4&A4&G4&A4&C5 (occurrences: 26)
# Merge 344: ('A4&A4', 'A4&B4') -> A4&A4&A4&B4 (occurrences: 26)
# Merge 345: ('A4&A4&B4', 'C5&B4') -> A4&A4&B4&C5&B4 (occurrences: 26)
# Merge 346: ('B4', 'A4&B4') -> B4&A4&B4 (occurrences: 26)
# Merge 347: ('C4', 'F4&F4') -> C4&F4&F4 (occurrences: 26)
# Merge 348: ('C5&C5&B4', 'C5&D5') -> C5&C5&B4&C5&D5 (occurrences: 26)
# Merge 349: ('D5&D5', 'F5') -> D5&D5&F5 (occurrences: 26)
# Merge 350: ('F4&D4', 'E4') -> F4&D4&E4 (occurrences: 26)
# Merge 351: ('F4&E4', 'F4&F4&E4') -> F4&E4&F4&F4&E4 (occurrences: 26)
# Merge 352: ('G4', 'A4&G4&A4') -> G4&A4&G4&A4 (occurrences: 26)
# Merge 353: ('G4&A4', 'C5&C5&B4') -> G4&A4&C5&C5&B4 (occurrences: 26)
# Merge 354: ('A4', 'A4&G4&A4') -> A4&A4&G4&A4 (occurrences: 25)
# Merge 355: ('A4', 'C5&D5&C5&B4') -> A4&C5&D5&C5&B4 (occurrences: 25)
# Merge 356: ('A4&A4', 'A4&A4&G4') -> A4&A4&A4&A4&G4 (occurrences: 25)
# Merge 357: ('A4&A4', 'C5&C5') -> A4&A4&C5&C5 (occurrences: 25)
# Merge 358: ('A4&B4', 'C5&A4&G4') -> A4&B4&C5&A4&G4 (occurrences: 25)
# Merge 359: ('A4&G4', 'F4') -> A4&G4&F4 (occurrences: 25)
# Merge 360: ('C4', 'A3') -> C4&A3 (occurrences: 25)
# Merge 361: ('C5', 'E5&D5') -> C5&E5&D5 (occurrences: 25)
# Merge 362: ('C5&B4', 'A4&C5') -> C5&B4&A4&C5 (occurrences: 25)
# Merge 363: ('D4', 'F4&E4&D4') -> D4&F4&E4&D4 (occurrences: 25)
# Merge 364: ('E4&E4', 'D4') -> E4&E4&D4 (occurrences: 25)
# Merge 365: ('E4&F4&G4', 'A4') -> E4&F4&G4&A4 (occurrences: 25)
# Merge 366: ('E5&F5', 'G5&F5') -> E5&F5&G5&F5 (occurrences: 25)
# Merge 367: ('F4&A4', 'C5&C5&D5') -> F4&A4&C5&C5&D5 (occurrences: 25)
# Merge 368: ('F4&G4&A4', 'F4&G4') -> F4&G4&A4&F4&G4 (occurrences: 25)
# Merge 369: ('G4&A4&C5', 'A4&A4') -> G4&A4&C5&A4&A4 (occurrences: 25)
# Merge 370: ('G4&E4', 'F4&F4&E4') -> G4&E4&F4&F4&E4 (occurrences: 25)
# Merge 371: ('G4&G4', 'C5&C5&B4') -> G4&G4&C5&C5&B4 (occurrences: 25)
# Merge 372: ('G4&G4', 'G4&A4') -> G4&G4&G4&A4 (occurrences: 25)
# Merge 373: ('C4&D4&D4', 'A4&A4') -> C4&D4&D4&A4&A4 (occurrences: 24)
# Merge 374: ('C5&D5', 'C5&D5') -> C5&D5&C5&D5 (occurrences: 24)
# Merge 375: ('C5&D5&C5', 'A4&B4') -> C5&D5&C5&A4&B4 (occurrences: 24)
# Merge 376: ('D4', 'C4&C4&D4') -> D4&C4&C4&D4 (occurrences: 24)
# Merge 377: ('D5&D5', 'D5') -> D5&D5&D5 (occurrences: 24)
# Merge 378: ('E4&F4&D4', 'E4') -> E4&F4&D4&E4 (occurrences: 24)
# Merge 379: ('F4&C4&D4', 'F4&E4') -> F4&C4&D4&F4&E4 (occurrences: 24)
# Merge 380: ('F4&D4&D4', 'D4&D4') -> F4&D4&D4&D4&D4 (occurrences: 24)
# Merge 381: ('F4&D4&D4', 'E4') -> F4&D4&D4&E4 (occurrences: 24)
# Merge 382: ('F4&D4&D4', 'F4&G4') -> F4&D4&D4&F4&G4 (occurrences: 24)
# Merge 383: ('G4&G4', 'G4&A4&C5') -> G4&G4&G4&A4&C5 (occurrences: 24)
# Merge 384: ('A4&A4', 'A4&C5') -> A4&A4&A4&C5 (occurrences: 23)
# Merge 385: ('A4&B4', 'C5&A4') -> A4&B4&C5&A4 (occurrences: 23)
# Merge 386: ('B4', 'C5&A4&G4') -> B4&C5&A4&G4 (occurrences: 23)
# Merge 387: ('C5&D5&D5&D5', 'D5') -> C5&D5&D5&D5&D5 (occurrences: 23)
# Merge 388: ('D4', 'G4') -> D4&G4 (occurrences: 23)
# Merge 389: ('D5&D5', 'C5&C5&D5') -> D5&D5&C5&C5&D5 (occurrences: 23)
# Merge 390: ('E4', 'F4&F4&D4') -> E4&F4&F4&D4 (occurrences: 23)
# Merge 391: ('E5&F5', 'E5') -> E5&F5&E5 (occurrences: 23)
# Merge 392: ('F4&F4', 'A4&C5&B4') -> F4&F4&A4&C5&B4 (occurrences: 23)
# Merge 393: ('A4&B4&B4', 'A4') -> A4&B4&B4&A4 (occurrences: 22)
# Merge 394: ('C4', 'C4&D4&D4') -> C4&C4&D4&D4 (occurrences: 22)
# Merge 395: ('D5', 'C5&C5&D5') -> D5&C5&C5&D5 (occurrences: 22)
# Merge 396: ('E4&F4&G4', 'A4&G4') -> E4&F4&G4&A4&G4 (occurrences: 22)
# Merge 397: ('E5&F5', 'E5&F5&D5') -> E5&F5&E5&F5&D5 (occurrences: 22)
# Merge 398: ('F4&A4&C5', 'G4') -> F4&A4&C5&G4 (occurrences: 22)
# Merge 399: ('F4&E4&D4', 'F4&F4') -> F4&E4&D4&F4&F4 (occurrences: 22)
# Merge 400: ('F4&E4&D4&D4', 'C4') -> F4&E4&D4&D4&C4 (occurrences: 22)
# Merge 401: ('G4', 'F4&G4&A4') -> G4&F4&G4&A4 (occurrences: 22)
# Merge 402: ('G4', 'F4&G4&A4&G4') -> G4&F4&G4&A4&G4 (occurrences: 22)
# Merge 403: ('A4&B4', 'A4&B4') -> A4&B4&A4&B4 (occurrences: 21)
# Merge 404: ('A4&C5', 'A4&G4&G4') -> A4&C5&A4&G4&G4 (occurrences: 21)
# Merge 405: ('C5&B4', 'A4&C5&B4') -> C5&B4&A4&C5&B4 (occurrences: 21)
# Merge 406: ('C5&C5&B4', 'A4&B4') -> C5&C5&B4&A4&B4 (occurrences: 21)
# Merge 407: ('C5&C5&B4', 'B4') -> C5&C5&B4&B4 (occurrences: 21)
# Merge 408: ('C5&C5&C5', 'G4&B4') -> C5&C5&C5&G4&B4 (occurrences: 21)
# Merge 409: ('C5&D5', 'C5&A4&G4') -> C5&D5&C5&A4&G4 (occurrences: 21)
# Merge 410: ('C5&D5&F5', 'E5&D5') -> C5&D5&F5&E5&D5 (occurrences: 21)
# Merge 411: ('D4', 'C4&F4&G4') -> D4&C4&F4&G4 (occurrences: 21)
# Merge 412: ('E4&F4&G4', 'F4&E4') -> E4&F4&G4&F4&E4 (occurrences: 21)
# Merge 413: ('F4', 'A4&G4&A4') -> F4&A4&G4&A4 (occurrences: 21)
# Merge 414: ('F4&A4', 'F4&G4') -> F4&A4&F4&G4 (occurrences: 21)
# Merge 415: ('F4&E4&D4&D4', 'A4') -> F4&E4&D4&D4&A4 (occurrences: 21)
# Merge 416: ('G4&G4', 'F4&G4&A4') -> G4&G4&F4&G4&A4 (occurrences: 21)
# Merge 417: ('A4', 'A4&G4&A4&B4') -> A4&A4&G4&A4&B4 (occurrences: 20)
# Merge 418: ('C4&D4&D4', 'F4&G4') -> C4&D4&D4&F4&G4 (occurrences: 20)
# Merge 419: ('C5', 'A4&G4&A4&G4') -> C5&A4&G4&A4&G4 (occurrences: 20)
# Merge 420: ('C5', 'A4&G4&G4') -> C5&A4&G4&G4 (occurrences: 20)
# Merge 421: ('C5&D5&D5', 'C5&B4') -> C5&D5&D5&C5&B4 (occurrences: 20)
# Merge 422: ('D4', 'E4') -> D4&E4 (occurrences: 20)
# Merge 423: ('D5', 'C5&D5&E5') -> D5&C5&D5&E5 (occurrences: 20)
# Merge 424: ('D5', 'E5&D5&C5&B4') -> D5&E5&D5&C5&B4 (occurrences: 20)
# Merge 425: ('E5&F5&G5', 'G5&F5') -> E5&F5&G5&G5&F5 (occurrences: 20)
# Merge 426: ('F4&E4&C4&D4', '') -> F4&E4&C4&D4& (occurrences: 20)
# Merge 427: ('G4&A4', 'A4&G4') -> G4&A4&A4&G4 (occurrences: 20)
# Merge 428: ('G4&G4', 'A4&A4') -> G4&G4&A4&A4 (occurrences: 20)
# Merge 429: ('A4', 'D5&C5&B4') -> A4&D5&C5&B4 (occurrences: 19)
# Merge 430: ('A4&C5', 'A4&C5') -> A4&C5&A4&C5 (occurrences: 19)
# Merge 431: ('C5', 'A4&G4&A4') -> C5&A4&G4&A4 (occurrences: 19)
# Merge 432: ('C5&C5&C5&C5', 'A4') -> C5&C5&C5&C5&A4 (occurrences: 19)
# Merge 433: ('C5&D5&B4', 'C5&B4') -> C5&D5&B4&C5&B4 (occurrences: 19)
# Merge 434: ('D5&D5', 'C5&B4') -> D5&D5&C5&B4 (occurrences: 19)
# Merge 435: ('E4&D4', 'C4&D4') -> E4&D4&C4&D4 (occurrences: 19)
# Merge 436: ('F4&E4', 'E4&F4&G4') -> F4&E4&E4&F4&G4 (occurrences: 19)
# Merge 437: ('F4&E4', 'G4&A4') -> F4&E4&G4&A4 (occurrences: 19)
# Merge 438: ('F4&E4&D4', 'F4&E4') -> F4&E4&D4&F4&E4 (occurrences: 19)
# Merge 439: ('F4&G4&A4&G4', '') -> F4&G4&A4&G4& (occurrences: 19)
# Merge 440: ('A4&A4&C5', 'A4&A4') -> A4&A4&C5&A4&A4 (occurrences: 18)
# Merge 441: ('A4&C5', 'A4&G4&A4') -> A4&C5&A4&G4&A4 (occurrences: 18)
# Merge 442: ('A4&G4&F4&G4', 'B4') -> A4&G4&F4&G4&B4 (occurrences: 18)
# Merge 443: ('A4&G4&G4', 'F4&F4') -> A4&G4&G4&F4&F4 (occurrences: 18)
# Merge 444: ('C5', 'A4&G4&A4&B4') -> C5&A4&G4&A4&B4 (occurrences: 18)
# Merge 445: ('C5&C5', 'A4&C5&B4') -> C5&C5&A4&C5&B4 (occurrences: 18)
# Merge 446: ('C5&D5', 'C5&D5&F5') -> C5&D5&C5&D5&F5 (occurrences: 18)
# Merge 447: ('D4&D4', 'D4&D4') -> D4&D4&D4&D4 (occurrences: 18)
# Merge 448: ('D5', 'C5&D5&C5&B4') -> D5&C5&D5&C5&B4 (occurrences: 18)
# Merge 449: ('D5&D5', 'D5&E5&D5') -> D5&D5&D5&E5&D5 (occurrences: 18)
# Merge 450: ('E4&D4', 'E4&E4') -> E4&D4&E4&E4 (occurrences: 18)
# Merge 451: ('E4&F4&E4&D4', 'C4') -> E4&F4&E4&D4&C4 (occurrences: 18)
# Merge 452: ('F4', 'B4') -> F4&B4 (occurrences: 18)
# Merge 453: ('F4&D4', 'F4&F4&G4') -> F4&D4&F4&F4&G4 (occurrences: 18)
# Merge 454: ('F4&E4&F4&G4', 'E4') -> F4&E4&F4&G4&E4 (occurrences: 18)
# Merge 455: ('F4&F4', 'C4') -> F4&F4&C4 (occurrences: 18)
# Merge 456: ('F4&G4', 'A4&B4') -> F4&G4&A4&B4 (occurrences: 18)
# Merge 457: ('G4&A4&C5', 'A4') -> G4&A4&C5&A4 (occurrences: 18)
# Merge 458: ('G4&G4', 'C5&B4') -> G4&G4&C5&B4 (occurrences: 18)
# Merge 459: ('G5', 'G5&F5') -> G5&G5&F5 (occurrences: 18)
# Merge 460: ('C5&C5&D5', 'C5&A4') -> C5&C5&D5&C5&A4 (occurrences: 17)
# Merge 461: ('C5&D5&C5', 'E5&D5') -> C5&D5&C5&E5&D5 (occurrences: 17)
# Merge 462: ('D5', 'C5&C5&B4') -> D5&C5&C5&B4 (occurrences: 17)
# Merge 463: ('F4', 'A4&A4&C5') -> F4&A4&A4&C5 (occurrences: 17)
# Merge 464: ('F4&A4', 'C5&D5') -> F4&A4&C5&D5 (occurrences: 17)
# Merge 465: ('F4&E4', 'E4&E4') -> F4&E4&E4&E4 (occurrences: 17)
# Merge 466: ('F4&E4', 'F4&F4&D4') -> F4&E4&F4&F4&D4 (occurrences: 17)
# Merge 467: ('F4&E4&G4&G4', 'A4') -> F4&E4&G4&G4&A4 (occurrences: 17)
# Merge 468: ('F4&F4&G4', 'A4&A4') -> F4&F4&G4&A4&A4 (occurrences: 17)
# Merge 469: ('F4&F4&G4', 'G4') -> F4&F4&G4&G4 (occurrences: 17)
# Merge 470: ('F4&G4', 'F4&E4&D4') -> F4&G4&F4&E4&D4 (occurrences: 17)
# Merge 471: ('F4&G4', 'G4&A4') -> F4&G4&G4&A4 (occurrences: 17)
# Merge 472: ('G4&A4&G4', 'E4&E4') -> G4&A4&G4&E4&E4 (occurrences: 17)
# Merge 473: ('G4&E4', 'F4&E4&D4') -> G4&E4&F4&E4&D4 (occurrences: 17)
# Merge 474: ('G5', 'G5&F5&E5&D5') -> G5&G5&F5&E5&D5 (occurrences: 17)
# Merge 475: ('A4&C5', 'G4&A4') -> A4&C5&G4&A4 (occurrences: 16)
# Merge 476: ('A4&G4', 'A4&G4&A4') -> A4&G4&A4&G4&A4 (occurrences: 16)
# Merge 477: ('B4', 'A4&G4') -> B4&A4&G4 (occurrences: 16)
# Merge 478: ('C5&C5&B4', 'A4&C5') -> C5&C5&B4&A4&C5 (occurrences: 16)
# Merge 479: ('C5&D5', 'E5&F5') -> C5&D5&E5&F5 (occurrences: 16)
# Merge 480: ('C5&D5&D5', 'E5&D5') -> C5&D5&D5&E5&D5 (occurrences: 16)
# Merge 481: ('C5&D5&D5&D5', 'E5') -> C5&D5&D5&D5&E5 (occurrences: 16)
# Merge 482: ('E4&D4', 'E4') -> E4&D4&E4 (occurrences: 16)
# Merge 483: ('E4&F4&D4&D4', 'D4') -> E4&F4&D4&D4&D4 (occurrences: 16)
# Merge 484: ('E5&E5&D5', 'E5&D5') -> E5&E5&D5&E5&D5 (occurrences: 16)
# Merge 485: ('F4&F4&D4', 'C4&D4') -> F4&F4&D4&C4&D4 (occurrences: 16)
# Merge 486: ('G4', 'C5&C5&D5') -> G4&C5&C5&D5 (occurrences: 16)
# Merge 487: ('G4&A4&G4', 'F4&F4') -> G4&A4&G4&F4&F4 (occurrences: 16)
# Merge 488: ('G4&G4', 'A4&C5&C5') -> G4&G4&A4&C5&C5 (occurrences: 16)
# Merge 489: ('A4&A4', 'C5&A4') -> A4&A4&C5&A4 (occurrences: 15)
# Merge 490: ('A4&B4', 'A4&A4&G4') -> A4&B4&A4&A4&G4 (occurrences: 15)
# Merge 491: ('A4&B4&C5&B4', 'A4') -> A4&B4&C5&B4&A4 (occurrences: 15)
# Merge 492: ('A4&G4', 'F4&A4') -> A4&G4&F4&A4 (occurrences: 15)
# Merge 493: ('A4&G4&A4&G4', 'F4') -> A4&G4&A4&G4&F4 (occurrences: 15)
# Merge 494: ('B3', 'C4&D4') -> B3&C4&D4 (occurrences: 15)
# Merge 495: ('C4&C4', 'C4') -> C4&C4&C4 (occurrences: 15)
# Merge 496: ('C4&D4&D4', 'C4&D4') -> C4&D4&D4&C4&D4 (occurrences: 15)
# Merge 497: ('C5', 'F5') -> C5&F5 (occurrences: 15)
# Merge 498: ('C5&C5&C5&B4', 'A4') -> C5&C5&C5&B4&A4 (occurrences: 15)
# Merge 499: ('C5&D5', 'A4&C5&B4') -> C5&D5&A4&C5&B4 (occurrences: 15)
# Merge 500: ('D4&C4&D4', 'F4&G4') -> D4&C4&D4&F4&G4 (occurrences: 15)
# Merge 501: ('D4&D4&D4', 'E4') -> D4&D4&D4&E4 (occurrences: 15)
# Merge 502: ('D5&B4', 'C5&D5') -> D5&B4&C5&D5 (occurrences: 15)
# Merge 503: ('D5&D5', 'E5&F5') -> D5&D5&E5&F5 (occurrences: 15)
# Merge 504: ('E4', 'F4&E4&F4&G4') -> E4&F4&E4&F4&G4 (occurrences: 15)
# Merge 505: ('F4&D4', 'C4&C4&D4') -> F4&D4&C4&C4&D4 (occurrences: 15)
# Merge 506: ('F4&D4', 'C4&F4&G4') -> F4&D4&C4&F4&G4 (occurrences: 15)
# Merge 507: ('F4&F4&E4', 'C4&D4') -> F4&F4&E4&C4&D4 (occurrences: 15)
# Merge 508: ('F4&F4&E4', 'G4&G4') -> F4&F4&E4&G4&G4 (occurrences: 15)
# Merge 509: ('F4&G4&G4', 'F4') -> F4&G4&G4&F4 (occurrences: 15)
# Merge 510: ('F5', 'E5') -> F5&E5 (occurrences: 15)
# Merge 511: ('G4', 'F4') -> G4&F4 (occurrences: 15)
# Merge 512: ('G4', 'F4&F4&G4') -> G4&F4&F4&G4 (occurrences: 15)
# Merge 513: ('G4&G4', 'C5&A4') -> G4&G4&C5&A4 (occurrences: 15)
# Merge 514: ('G5&A5', 'A5') -> G5&A5&A5 (occurrences: 15)
# Merge 515: ('A3&C4&D4', 'F4&D4') -> A3&C4&D4&F4&D4 (occurrences: 14)
# Merge 516: ('A4&B4', 'C5&C5') -> A4&B4&C5&C5 (occurrences: 14)
# Merge 517: ('A4&C5', 'A4&B4') -> A4&C5&A4&B4 (occurrences: 14)
# Merge 518: ('A4&G4&F4&G4', 'D4') -> A4&G4&F4&G4&D4 (occurrences: 14)
# Merge 519: ('A4&G4&G4', 'F4') -> A4&G4&G4&F4 (occurrences: 14)
# Merge 520: ('C4&D4&D4', 'C4') -> C4&D4&D4&C4 (occurrences: 14)
# Merge 521: ('C5', 'A4&A4&A4&A4') -> C5&A4&A4&A4&A4 (occurrences: 14)
# Merge 522: ('C5&B4', 'A4&A4') -> C5&B4&A4&A4 (occurrences: 14)
# Merge 523: ('C5&D5', 'E5&E5&D5') -> C5&D5&E5&E5&D5 (occurrences: 14)
# Merge 524: ('C5&D5&C5&B4', 'B4') -> C5&D5&C5&B4&B4 (occurrences: 14)
# Merge 525: ('F4&E4', 'F4&F4&G4') -> F4&E4&F4&F4&G4 (occurrences: 14)
# Merge 526: ('F4&F4', 'F4&F4&D4') -> F4&F4&F4&F4&D4 (occurrences: 14)
# Merge 527: ('F4&F4&D4', 'C4') -> F4&F4&D4&C4 (occurrences: 14)
# Merge 528: ('F5&F5', 'E5&D5') -> F5&F5&E5&D5 (occurrences: 14)
# Merge 529: ('G4&G4', 'C5&A4&G4') -> G4&G4&C5&A4&G4 (occurrences: 14)
# Merge 530: ('A4', 'F4&A4') -> A4&F4&A4 (occurrences: 13)
# Merge 531: ('A4&C5&B4', 'A4&G4') -> A4&C5&B4&A4&G4 (occurrences: 13)
# Merge 532: ('A4&G4', 'F4&F4') -> A4&G4&F4&F4 (occurrences: 13)
# Merge 533: ('C5&B4', 'C5&A4') -> C5&B4&C5&A4 (occurrences: 13)
# Merge 534: ('C5&C5&B4', 'A4&A4') -> C5&C5&B4&A4&A4 (occurrences: 13)
# Merge 535: ('C5&C5&D5', 'E5') -> C5&C5&D5&E5 (occurrences: 13)
# Merge 536: ('C5&D5&B4', 'C5&D5') -> C5&D5&B4&C5&D5 (occurrences: 13)
# Merge 537: ('D4', 'F4&E4&F4&D4') -> D4&F4&E4&F4&D4 (occurrences: 13)
# Merge 538: ('D4&E4&D4', 'C4&D4') -> D4&E4&D4&C4&D4 (occurrences: 13)
# Merge 539: ('D5&D5', 'E5') -> D5&D5&E5 (occurrences: 13)
# Merge 540: ('D5&F5', 'D5') -> D5&F5&D5 (occurrences: 13)
# Merge 541: ('E4', 'F4') -> E4&F4 (occurrences: 13)
# Merge 542: ('E4&F4&G4', 'G4&A4') -> E4&F4&G4&G4&A4 (occurrences: 13)
# Merge 543: ('E4&F4&G4', 'G4&E4') -> E4&F4&G4&G4&E4 (occurrences: 13)
# Merge 544: ('E5', 'C5') -> E5&C5 (occurrences: 13)
# Merge 545: ('F4&A4', 'F4&G4&A4') -> F4&A4&F4&G4&A4 (occurrences: 13)
# Merge 546: ('F4&D4', 'F4&C4&D4') -> F4&D4&F4&C4&D4 (occurrences: 13)
# Merge 547: ('F4&D4', 'F4&D4&D4') -> F4&D4&F4&D4&D4 (occurrences: 13)
# Merge 548: ('F4&D4', 'F4&G4&A4') -> F4&D4&F4&G4&A4 (occurrences: 13)
# Merge 549: ('G4&A4&G4', 'F4') -> G4&A4&G4&F4 (occurrences: 13)
# Merge 550: ('G4&A4&G4', 'F4&D4') -> G4&A4&G4&F4&D4 (occurrences: 13)
# Merge 551: ('G4&G4', 'A4&B4&A4') -> G4&G4&A4&B4&A4 (occurrences: 13)
# Merge 552: ('A3', 'C4') -> A3&C4 (occurrences: 12)
# Merge 553: ('A3', 'G3') -> A3&G3 (occurrences: 12)
# Merge 554: ('A4&B4&C5&B4', 'B4') -> A4&B4&C5&B4&B4 (occurrences: 12)
# Merge 555: ('A4&G4', 'C5&B4') -> A4&G4&C5&B4 (occurrences: 12)
# Merge 556: ('A4&G4', 'E4') -> A4&G4&E4 (occurrences: 12)
# Merge 557: ('A4&G4&G4', 'B4') -> A4&G4&G4&B4 (occurrences: 12)
# Merge 558: ('B4&B4', 'B4&B4') -> B4&B4&B4&B4 (occurrences: 12)
# Merge 559: ('C4', 'F4&G4&A4') -> C4&F4&G4&A4 (occurrences: 12)
# Merge 560: ('C4&C4', 'B3') -> C4&C4&B3 (occurrences: 12)
# Merge 561: ('C4&D4&D4', 'A4') -> C4&D4&D4&A4 (occurrences: 12)
# Merge 562: ('C4&D4&D4', 'A4&C5') -> C4&D4&D4&A4&C5 (occurrences: 12)
# Merge 563: ('C5', 'E5&F5&E5&D5') -> C5&E5&F5&E5&D5 (occurrences: 12)
# Merge 564: ('C5&B4', 'G4') -> C5&B4&G4 (occurrences: 12)
# Merge 565: ('C5&C5', 'G4&G4') -> C5&C5&G4&G4 (occurrences: 12)
# Merge 566: ('C5&C5&D5', 'F5') -> C5&C5&D5&F5 (occurrences: 12)
# Merge 567: ('C5&D5&E5&D5', 'B4') -> C5&D5&E5&D5&B4 (occurrences: 12)
# Merge 568: ('D4', 'E4&F4&G4&G4') -> D4&E4&F4&G4&G4 (occurrences: 12)
# Merge 569: ('D4&D4', 'F4&G4') -> D4&D4&F4&G4 (occurrences: 12)
# Merge 570: ('D5&E5&D5', 'D5') -> D5&E5&D5&D5 (occurrences: 12)
# Merge 571: ('E4&F4&G4', 'E4') -> E4&F4&G4&E4 (occurrences: 12)
# Merge 572: ('F4', 'A4&A4&A4&A4') -> F4&A4&A4&A4&A4 (occurrences: 12)
# Merge 573: ('F4', 'C4&C4') -> F4&C4&C4 (occurrences: 12)
# Merge 574: ('F4', 'C4&D4&D4&D4') -> F4&C4&D4&D4&D4 (occurrences: 12)
# Merge 575: ('F4&A4', 'D4') -> F4&A4&D4 (occurrences: 12)
# Merge 576: ('F4&E4', 'C4&F4&G4') -> F4&E4&C4&F4&G4 (occurrences: 12)
# Merge 577: ('F4&F4', 'F4&F4&E4') -> F4&F4&F4&F4&E4 (occurrences: 12)
# Merge 578: ('F4&G4', 'A4&G4&A4') -> F4&G4&A4&G4&A4 (occurrences: 12)
# Merge 579: ('F4&G4', 'F4&F4') -> F4&G4&F4&F4 (occurrences: 12)
# Merge 580: ('F4&G4', 'F4&F4&G4') -> F4&G4&F4&F4&G4 (occurrences: 12)
# Merge 581: ('F4&G4', 'F4&G4&A4') -> F4&G4&F4&G4&A4 (occurrences: 12)
# Merge 582: ('F4&G4&A4&A4', 'A4') -> F4&G4&A4&A4&A4 (occurrences: 12)
# Merge 583: ('G4', 'F4&E4&D4') -> G4&F4&E4&D4 (occurrences: 12)
# Merge 584: ('G4&G4&G4', 'F4&G4') -> G4&G4&G4&F4&G4 (occurrences: 12)
# Merge 585: ('G5&A5', 'G5&F5') -> G5&A5&G5&F5 (occurrences: 12)
# Merge 586: ('A4', 'A4&G4&G4&G4') -> A4&A4&G4&G4&G4 (occurrences: 11)
# Merge 587: ('A4&B4', 'C5&D5') -> A4&B4&C5&D5 (occurrences: 11)
# Merge 588: ('B4', 'A4') -> B4&A4 (occurrences: 11)
# Merge 589: ('B4', 'C5&B4&A4&G4') -> B4&C5&B4&A4&G4 (occurrences: 11)
# Merge 590: ('C4&D4&D4', 'F4&F4') -> C4&D4&D4&F4&F4 (occurrences: 11)
# Merge 591: ('C5', 'A4&A4&B4') -> C5&A4&A4&B4 (occurrences: 11)
# Merge 592: ('C5', 'A4&G4&A4&C5') -> C5&A4&G4&A4&C5 (occurrences: 11)
# Merge 593: ('C5', 'F4&A4') -> C5&F4&A4 (occurrences: 11)
# Merge 594: ('C5', 'G4&A4&C5') -> C5&G4&A4&C5 (occurrences: 11)
# Merge 595: ('C5&B4', 'A4&G4&G4') -> C5&B4&A4&G4&G4 (occurrences: 11)
# Merge 596: ('C5&C5&D5', 'C5') -> C5&C5&D5&C5 (occurrences: 11)
# Merge 597: ('C5&D5&D5', 'C5&C5') -> C5&D5&D5&C5&C5 (occurrences: 11)
# Merge 598: ('D4', 'C4&D4&D4') -> D4&C4&D4&D4 (occurrences: 11)
# Merge 599: ('D4', 'G4&A4&G4') -> D4&G4&A4&G4 (occurrences: 11)
# Merge 600: ('D4&C4', 'B3') -> D4&C4&B3 (occurrences: 11)
# Merge 601: ('D5&D5', 'D5&C5&B4') -> D5&D5&D5&C5&B4 (occurrences: 11)
# Merge 602: ('E4&E4', 'F4&E4&D4') -> E4&E4&F4&E4&D4 (occurrences: 11)
# Merge 603: ('E4&F4&D4&D4', 'E4') -> E4&F4&D4&D4&E4 (occurrences: 11)
# Merge 604: ('E5&D5', 'E5') -> E5&D5&E5 (occurrences: 11)
# Merge 605: ('F4&D4', 'F4&E4&D4') -> F4&D4&F4&E4&D4 (occurrences: 11)
# Merge 606: ('F4&D4&D4', 'A4&A4') -> F4&D4&D4&A4&A4 (occurrences: 11)
# Merge 607: ('F4&D4&D4', 'F4&F4') -> F4&D4&D4&F4&F4 (occurrences: 11)
# Merge 608: ('F4&E4', 'F4&E4') -> F4&E4&F4&E4 (occurrences: 11)
# Merge 609: ('F4&E4', 'G4&E4') -> F4&E4&G4&E4 (occurrences: 11)
# Merge 610: ('F4&F4', 'A4&C5&C5') -> F4&F4&A4&C5&C5 (occurrences: 11)
# Merge 611: ('F4&F4', 'F4&A4') -> F4&F4&F4&A4 (occurrences: 11)
# Merge 612: ('F4&F4', 'F4&G4&A4') -> F4&F4&F4&G4&A4 (occurrences: 11)
# Merge 613: ('F4&F4&E4', 'F4&E4') -> F4&F4&E4&F4&E4 (occurrences: 11)
# Merge 614: ('G4&A4', 'C5&D5&D5') -> G4&A4&C5&D5&D5 (occurrences: 11)
# Merge 615: ('G4&A4', 'F4&E4&D4') -> G4&A4&F4&E4&D4 (occurrences: 11)
# Merge 616: ('G4&A4', 'F4&F4&G4') -> G4&A4&F4&F4&G4 (occurrences: 11)
# Merge 617: ('G4&G4', 'G4&A4&G4') -> G4&G4&G4&A4&G4 (occurrences: 11)
# Merge 618: ('A4&A4', 'A4&C5&A4') -> A4&A4&A4&C5&A4 (occurrences: 10)
# Merge 619: ('A4&A4', 'A4&G4&A4') -> A4&A4&A4&G4&A4 (occurrences: 10)
# Merge 620: ('A4&A4&B4', 'A4') -> A4&A4&B4&A4 (occurrences: 10)
# Merge 621: ('A4&B4', 'A4&G4&A4') -> A4&B4&A4&G4&A4 (occurrences: 10)
# Merge 622: ('A4&B4', 'G4&F4&G4') -> A4&B4&G4&F4&G4 (occurrences: 10)
# Merge 623: ('A4&C5&B4', 'A4&C5') -> A4&C5&B4&A4&C5 (occurrences: 10)
# Merge 624: ('A4&C5&C5', 'G4&G4') -> A4&C5&C5&G4&G4 (occurrences: 10)
# Merge 625: ('A4&G4', 'E4&G4&E4') -> A4&G4&E4&G4&E4 (occurrences: 10)
# Merge 626: ('A4&G4', 'F4&E4&E4') -> A4&G4&F4&E4&E4 (occurrences: 10)
# Merge 627: ('A4&G4&A4', 'C5&D5') -> A4&G4&A4&C5&D5 (occurrences: 10)
# Merge 628: ('C4', 'F4&G4&A4&G4') -> C4&F4&G4&A4&G4 (occurrences: 10)
# Merge 629: ('C4&D4', 'C4&D4') -> C4&D4&C4&D4 (occurrences: 10)
# Merge 630: ('C4&D4', 'F4&E4&D4') -> C4&D4&F4&E4&D4 (occurrences: 10)
# Merge 631: ('C5&A4', 'C5&D5') -> C5&A4&C5&D5 (occurrences: 10)
# Merge 632: ('C5&D5&C5', 'A4&A4') -> C5&D5&C5&A4&A4 (occurrences: 10)
# Merge 633: ('C5&D5&E5&D5', 'E5') -> C5&D5&E5&D5&E5 (occurrences: 10)
# Merge 634: ('D4', 'F4&D4&C4') -> D4&F4&D4&C4 (occurrences: 10)
# Merge 635: ('D4', 'F4&D4&C4&D4') -> D4&F4&D4&C4&D4 (occurrences: 10)
# Merge 636: ('D4&D4', 'D4&C4&D4') -> D4&D4&D4&C4&D4 (occurrences: 10)
# Merge 637: ('E4', 'G4&G4') -> E4&G4&G4 (occurrences: 10)
# Merge 638: ('E5&D5', 'D5') -> E5&D5&D5 (occurrences: 10)
# Merge 639: ('E5&F5&D5', 'C5&C5') -> E5&F5&D5&C5&C5 (occurrences: 10)
# Merge 640: ('E5&F5&E5&D5', 'F5') -> E5&F5&E5&D5&F5 (occurrences: 10)
# Merge 641: ('F4', 'A4&A4&A4&G4') -> F4&A4&A4&A4&G4 (occurrences: 10)
# Merge 642: ('F4&D4', 'F4&D4&C4') -> F4&D4&F4&D4&C4 (occurrences: 10)
# Merge 643: ('F4&D4&D4&D4', 'E4') -> F4&D4&D4&D4&E4 (occurrences: 10)
# Merge 644: ('F4&E4&F4&D4', 'C4') -> F4&E4&F4&D4&C4 (occurrences: 10)
# Merge 645: ('F4&G4', 'F4&D4') -> F4&G4&F4&D4 (occurrences: 10)
# Merge 646: ('F4&G4', 'F4&F4&D4') -> F4&G4&F4&F4&D4 (occurrences: 10)
# Merge 647: ('F4&G4', 'G4&A4&G4') -> F4&G4&G4&A4&G4 (occurrences: 10)
# Merge 648: ('F4&G4&G4', 'F4&F4') -> F4&G4&G4&F4&F4 (occurrences: 10)
# Merge 649: ('G4', 'A4&A4&A4&A4') -> G4&A4&A4&A4&A4 (occurrences: 10)
# Merge 650: ('G4', 'C5&C5') -> G4&C5&C5 (occurrences: 10)
# Merge 651: ('G4&G4&G4', 'B4') -> G4&G4&G4&B4 (occurrences: 10)
# Merge 652: ('G4&G4&G4', 'C5&B4') -> G4&G4&G4&C5&B4 (occurrences: 10)
# Merge 653: ('A3', 'B3') -> A3&B3 (occurrences: 9)
# Merge 654: ('A4&A4&B4', 'A4&A4') -> A4&A4&B4&A4&A4 (occurrences: 9)
# Merge 655: ('A4&A4&C5', 'G4&G4') -> A4&A4&C5&G4&G4 (occurrences: 9)
# Merge 656: ('A4&B4&C5', 'A4&A4') -> A4&B4&C5&A4&A4 (occurrences: 9)
# Merge 657: ('A4&C5', 'A4&C5&C5') -> A4&C5&A4&C5&C5 (occurrences: 9)
# Merge 658: ('A4&C5&C5', 'G4') -> A4&C5&C5&G4 (occurrences: 9)
# Merge 659: ('A4&G4', 'A4&A4&A4') -> A4&G4&A4&A4&A4 (occurrences: 9)
# Merge 660: ('A4&G4', 'C5&C5') -> A4&G4&C5&C5 (occurrences: 9)
# Merge 661: ('A4&G4', 'E4&E4') -> A4&G4&E4&E4 (occurrences: 9)
# Merge 662: ('A4&G4', 'F4&A4&G4') -> A4&G4&F4&A4&G4 (occurrences: 9)
# Merge 663: ('A4&G4&A4&G4', 'D4') -> A4&G4&A4&G4&D4 (occurrences: 9)
# Merge 664: ('A4&G4&G4', 'A4&A4') -> A4&G4&G4&A4&A4 (occurrences: 9)
# Merge 665: ('A5', 'G5&F5') -> A5&G5&F5 (occurrences: 9)
# Merge 666: ('B4', 'A4&G4&A4&B4') -> B4&A4&G4&A4&B4 (occurrences: 9)
# Merge 667: ('B4&B4', 'B4') -> B4&B4&B4 (occurrences: 9)
# Merge 668: ('C4&C4&D4', 'F4&D4') -> C4&C4&D4&F4&D4 (occurrences: 9)
# Merge 669: ('C4&C4&D4', 'F4&F4') -> C4&C4&D4&F4&F4 (occurrences: 9)
# Merge 670: ('C5', 'A4&A4&A4&G4') -> C5&A4&A4&A4&G4 (occurrences: 9)
# Merge 671: ('C5', 'A4&G4&G4&G4') -> C5&A4&G4&G4&G4 (occurrences: 9)
# Merge 672: ('C5', 'G4&G4') -> C5&G4&G4 (occurrences: 9)
# Merge 673: ('C5&B4', 'A4&C5&C5') -> C5&B4&A4&C5&C5 (occurrences: 9)
# Merge 674: ('C5&C5&B4', 'C5&C5') -> C5&C5&B4&C5&C5 (occurrences: 9)
# Merge 675: ('C5&D5', 'A4') -> C5&D5&A4 (occurrences: 9)
# Merge 676: ('C5&D5', 'C5&D5&B4') -> C5&D5&C5&D5&B4 (occurrences: 9)
# Merge 677: ('C5&D5&E5&D5', 'C5') -> C5&D5&E5&D5&C5 (occurrences: 9)
# Merge 678: ('D4', 'F4&D4&D4') -> D4&F4&D4&D4 (occurrences: 9)
# Merge 679: ('D4', 'G4&F4&G4') -> D4&G4&F4&G4 (occurrences: 9)
# Merge 680: ('D5&B4', 'C5&B4') -> D5&B4&C5&B4 (occurrences: 9)
# Merge 681: ('D5&F5', 'D5&F5') -> D5&F5&D5&F5 (occurrences: 9)
# Merge 682: ('E4', 'C4&D4') -> E4&C4&D4 (occurrences: 9)
# Merge 683: ('E4&E4', 'E4&D4') -> E4&E4&E4&D4 (occurrences: 9)
# Merge 684: ('E4&F4&G4', 'F4&D4') -> E4&F4&G4&F4&D4 (occurrences: 9)
# Merge 685: ('E4&G4', 'A4&A4') -> E4&G4&A4&A4 (occurrences: 9)
# Merge 686: ('E4&G4', 'E4&E4') -> E4&G4&E4&E4 (occurrences: 9)
# Merge 687: ('E5', 'E5&E5&D5') -> E5&E5&E5&D5 (occurrences: 9)
# Merge 688: ('F4', 'A4&C5&A4') -> F4&A4&C5&A4 (occurrences: 9)
# Merge 689: ('F4&A4', 'A4&G4') -> F4&A4&A4&G4 (occurrences: 9)
# Merge 690: ('F4&E4&F4&G4', 'D4') -> F4&E4&F4&G4&D4 (occurrences: 9)
# Merge 691: ('F4&F4&F4&E4', 'C4') -> F4&F4&F4&E4&C4 (occurrences: 9)
# Merge 692: ('F4&F4&G4', 'A4&C5') -> F4&F4&G4&A4&C5 (occurrences: 9)
# Merge 693: ('F4&G4', 'E4&F4&D4') -> F4&G4&E4&F4&D4 (occurrences: 9)
# Merge 694: ('F4&G4&G4', 'A4&C5') -> F4&G4&G4&A4&C5 (occurrences: 9)
# Merge 695: ('G4', 'D5&D5&D5&D5') -> G4&D5&D5&D5&D5 (occurrences: 9)
# Merge 696: ('G4', 'F4&A4&C5&C5') -> G4&F4&A4&C5&C5 (occurrences: 9)
# Merge 697: ('G4&A4', 'C5&B4&A4') -> G4&A4&C5&B4&A4 (occurrences: 9)
# Merge 698: ('G4&A4&B4', 'B4') -> G4&A4&B4&B4 (occurrences: 9)
# Merge 699: ('G4&A4&C5', 'A4&G4') -> G4&A4&C5&A4&G4 (occurrences: 9)
# Merge 700: ('G4&A4&G4&G4', 'F4') -> G4&A4&G4&G4&F4 (occurrences: 9)
# Merge 701: ('G4&E4', 'F4&F4') -> G4&E4&F4&F4 (occurrences: 9)
# Merge 702: ('G4&G4', 'F4&E4&D4') -> G4&G4&F4&E4&D4 (occurrences: 9)
# Merge 703: ('G4&G4', 'F4&F4&G4') -> G4&G4&F4&F4&G4 (occurrences: 9)
# Merge 704: ('G5&F5&E5&D5', 'F5') -> G5&F5&E5&D5&F5 (occurrences: 9)
# Merge 705: ('A4', 'A4&G4&A4&G4') -> A4&A4&G4&A4&G4 (occurrences: 8)
# Merge 706: ('A4&A4&G4', 'C5&C5') -> A4&A4&G4&C5&C5 (occurrences: 8)
# Merge 707: ('A4&B4', 'A4&F4&G4') -> A4&B4&A4&F4&G4 (occurrences: 8)
# Merge 708: ('A4&B4&B4', 'A4&A4') -> A4&B4&B4&A4&A4 (occurrences: 8)
# Merge 709: ('A4&C5&B4', 'C5&B4') -> A4&C5&B4&C5&B4 (occurrences: 8)
# Merge 710: ('B3', 'C4&D4&D4') -> B3&C4&D4&D4 (occurrences: 8)
# Merge 711: ('B4&B4', 'A4&B4') -> B4&B4&A4&B4 (occurrences: 8)
# Merge 712: ('B5', 'A5') -> B5&A5 (occurrences: 8)
# Merge 713: ('C4&B3', 'C4&D4&D4') -> C4&B3&C4&D4&D4 (occurrences: 8)
# Merge 714: ('C4&C4', 'E4&F4&G4') -> C4&C4&E4&F4&G4 (occurrences: 8)
# Merge 715: ('C4&D4', 'F4&D4&D4') -> C4&D4&F4&D4&D4 (occurrences: 8)
# Merge 716: ('C4&D4&D4&D4', 'E4') -> C4&D4&D4&D4&E4 (occurrences: 8)
# Merge 717: ('C5', 'A4&B4&C5') -> C5&A4&B4&C5 (occurrences: 8)
# Merge 718: ('C5&A4', 'C5&C5&B4') -> C5&A4&C5&C5&B4 (occurrences: 8)
# Merge 719: ('C5&A4', 'C5&C5&D5') -> C5&A4&C5&C5&D5 (occurrences: 8)
# Merge 720: ('C5&B4', 'A4&A4&G4') -> C5&B4&A4&A4&G4 (occurrences: 8)
# Merge 721: ('C5&B4', 'C5&D5&C5') -> C5&B4&C5&D5&C5 (occurrences: 8)
# Merge 722: ('C5&C5&A4', 'C5&D5') -> C5&C5&A4&C5&D5 (occurrences: 8)
# Merge 723: ('C5&C5&C5', 'A4&B4') -> C5&C5&C5&A4&B4 (occurrences: 8)
# Merge 724: ('C5&C5&C5&B4', 'B4') -> C5&C5&C5&B4&B4 (occurrences: 8)
# Merge 725: ('C5&D5', 'A4&A4&G4') -> C5&D5&A4&A4&G4 (occurrences: 8)
# Merge 726: ('C5&D5', 'G4') -> C5&D5&G4 (occurrences: 8)
# Merge 727: ('C5&D5&F5', 'F5') -> C5&D5&F5&F5 (occurrences: 8)
# Merge 728: ('D4', 'C4&C4') -> D4&C4&C4 (occurrences: 8)
# Merge 729: ('D4&C4', 'F4&G4&A4') -> D4&C4&F4&G4&A4 (occurrences: 8)
# Merge 730: ('D4&D4', 'E4') -> D4&D4&E4 (occurrences: 8)
# Merge 731: ('D5', 'E5&E5&D5') -> D5&E5&E5&D5 (occurrences: 8)
# Merge 732: ('D5&D5', 'C5&D5&E5') -> D5&D5&C5&D5&E5 (occurrences: 8)
# Merge 733: ('D5&D5&B4', 'C5&D5') -> D5&D5&B4&C5&D5 (occurrences: 8)
# Merge 734: ('D5&E5&F5', 'G5&F5') -> D5&E5&F5&G5&F5 (occurrences: 8)
# Merge 735: ('E4&D4', 'E4&F4&G4') -> E4&D4&E4&F4&G4 (occurrences: 8)
# Merge 736: ('E4&F4&G4', 'E4&E4') -> E4&F4&G4&E4&E4 (occurrences: 8)
# Merge 737: ('E5&E5&D5', 'D5&E5') -> E5&E5&D5&D5&E5 (occurrences: 8)
# Merge 738: ('E5&F5', 'D5&C5&B4') -> E5&F5&D5&C5&B4 (occurrences: 8)
# Merge 739: ('F4', 'A4&G4&A4&G4') -> F4&A4&G4&A4&G4 (occurrences: 8)
# Merge 740: ('F4&A4', 'A4&G4&G4') -> F4&A4&A4&G4&G4 (occurrences: 8)
# Merge 741: ('F4&D4', 'C4&C4') -> F4&D4&C4&C4 (occurrences: 8)
# Merge 742: ('F4&D4', 'E4&F4&D4') -> F4&D4&E4&F4&D4 (occurrences: 8)
# Merge 743: ('F4&D4', 'F4&E4') -> F4&D4&F4&E4 (occurrences: 8)
# Merge 744: ('F5', 'D5&D5') -> F5&D5&D5 (occurrences: 8)
# Merge 745: ('G4', 'A4&G4&A4&C5') -> G4&A4&G4&A4&C5 (occurrences: 8)
# Merge 746: ('G4', 'F4&E4&D4&D4') -> G4&F4&E4&D4&D4 (occurrences: 8)
# Merge 747: ('G4', 'F4&E4&D4&E4') -> G4&F4&E4&D4&E4 (occurrences: 8)
# Merge 748: ('G4&A4', 'C5&C5&D5') -> G4&A4&C5&C5&D5 (occurrences: 8)
# Merge 749: ('G4&A4&C5', 'A4&B4') -> G4&A4&C5&A4&B4 (occurrences: 8)
# Merge 750: ('G4&B4', 'C5&A4&G4') -> G4&B4&C5&A4&G4 (occurrences: 8)
# Merge 751: ('G4&G4', 'A4&C5&A4') -> G4&G4&A4&C5&A4 (occurrences: 8)
# Merge 752: ('G5', 'G5&A5') -> G5&G5&A5 (occurrences: 8)
# Merge 753: ('A4', 'C5&D5&B4') -> A4&C5&D5&B4 (occurrences: 7)
# ...
# Merge 777: ('C5&D5&B4', 'C5&A4') -> C5&D5&B4&C5&A4 (occurrences: 7)
# Merge 778: ('C5&D5&D5', 'F5') -> C5&D5&D5&F5 (occurrences: 7)
# Merge 779: ('D4', 'A4&A4') -> D4&A4&A4 (occurrences: 7)
# Merge 780: ('D4', 'A4&A4&G4') -> D4&A4&A4&G4 (occurrences: 7)
# Merge 781: ('D4', 'F4&F4') -> D4&F4&F4 (occurrences: 7)
# Merge 782: ('D4', 'F4&F4&E4') -> D4&F4&F4&E4 (occurrences: 7)
# Merge 783: ('D4', 'F4&G4&A4') -> D4&F4&G4&A4 (occurrences: 7)
# Merge 784: ('D4&C4&D4', 'F4&F4') -> D4&C4&D4&F4&F4 (occurrences: 7)
# Merge 785: ('D5', 'C5&D5&D5&D5') -> D5&C5&D5&D5&D5 (occurrences: 7)
# Merge 786: ('D5&C5&B4', 'C5&D5') -> D5&C5&B4&C5&D5 (occurrences: 7)
# Merge 787: ('D5&D5', 'C5&A4') -> D5&D5&C5&A4 (occurrences: 7)
# Merge 788: ('D5&D5', 'D5&F5') -> D5&D5&D5&F5 (occurrences: 7)
# Merge 789: ('D5&E5', 'C5&A4') -> D5&E5&C5&A4 (occurrences: 7)
# Merge 790: ('D5&E5&F5', 'E5') -> D5&E5&F5&E5 (occurrences: 7)
# Merge 791: ('E4', 'F4&A4&A4') -> E4&F4&A4&A4 (occurrences: 7)
# Merge 792: ('E4&D4', 'G4&A4') -> E4&D4&G4&A4 (occurrences: 7)
# Merge 793: ('E4&E4', 'G4&A4') -> E4&E4&G4&A4 (occurrences: 7)
# Merge 794: ('E4&F4&G4', 'F4&F4') -> E4&F4&G4&F4&F4 (occurrences: 7)
# Merge 795: ('E4&F4&G4&G4', 'D4') -> E4&F4&G4&G4&D4 (occurrences: 7)
# Merge 796: ('E5&D5', 'C5&C5&B4') -> E5&D5&C5&C5&B4 (occurrences: 7)
# Merge 797: ('E5&D5', 'C5&D5&D5') -> E5&D5&C5&D5&D5 (occurrences: 7)
# Merge 798: ('E5&F5', 'E5&F5') -> E5&F5&E5&F5 (occurrences: 7)
# Merge 799: ('E5&F5&G5&F5', 'F5') -> E5&F5&G5&F5&F5 (occurrences: 7)
# Merge 800: ('F4&C4&D4', 'F4&G4') -> F4&C4&D4&F4&G4 (occurrences: 7)
# Merge 801: ('F4&D4&D4', 'F4&E4') -> F4&D4&D4&F4&E4 (occurrences: 7)
# Merge 802: ('F4&D4&D4', 'G4&G4') -> F4&D4&D4&G4&G4 (occurrences: 7)
# Merge 803: ('F4&E4&D4', 'A4&A4') -> F4&E4&D4&A4&A4 (occurrences: 7)
# Merge 804: ('F4&E4&D4', 'G4&G4') -> F4&E4&D4&G4&G4 (occurrences: 7)
# Merge 805: ('F4&F4', 'F4&C4&D4') -> F4&F4&F4&C4&D4 (occurrences: 7)
# Merge 806: ('F4&F4', 'F4&D4&D4') -> F4&F4&F4&D4&D4 (occurrences: 7)
# Merge 807: ('F4&F4&D4', 'F4&F4') -> F4&F4&D4&F4&F4 (occurrences: 7)
# Merge 808: ('F4&F4&F4&E4', 'G4') -> F4&F4&F4&E4&G4 (occurrences: 7)
# Merge 809: ('F4&F4&G4', 'G4&E4') -> F4&F4&G4&G4&E4 (occurrences: 7)
# Merge 810: ('G4', 'A4&G4&A4&G4') -> G4&A4&G4&A4&G4 (occurrences: 7)
# Merge 811: ('G4', 'C5&B4&C5&D5') -> G4&C5&B4&C5&D5 (occurrences: 7)
# Merge 812: ('G4', 'C5&C5&C5&C5') -> G4&C5&C5&C5&C5 (occurrences: 7)
# Merge 813: ('G4', 'C5&C5&G4&B4') -> G4&C5&C5&G4&B4 (occurrences: 7)
# Merge 814: ('G4', 'E4&E4') -> G4&E4&E4 (occurrences: 7)
# Merge 815: ('G4&A4', 'F4&F4') -> G4&A4&F4&F4 (occurrences: 7)
# Merge 816: ('G4&B4', 'C5&D5&D5') -> G4&B4&C5&D5&D5 (occurrences: 7)
# Merge 817: ('G4&E4', 'G4&A4&G4') -> G4&E4&G4&A4&G4 (occurrences: 7)
# Merge 818: ('G4&G4', 'A4&G4&A4') -> G4&G4&A4&G4&A4 (occurrences: 7)
# Merge 819: ('G4&G4', 'C5') -> G4&G4&C5 (occurrences: 7)
# Merge 820: ('G5&A5', 'G5') -> G5&A5&G5 (occurrences: 7)
# Merge 821: ('', '') -> & (occurrences: 6)
# Merge 822: ('A4', 'C5&C5&C5&C5') -> A4&C5&C5&C5&C5 (occurrences: 6)
# Merge 823: ('A4&A4', 'F4&A4&G4') -> A4&A4&F4&A4&G4 (occurrences: 6)
# Merge 824: ('A4&A4&G4', 'A4&A4') -> A4&A4&G4&A4&A4 (occurrences: 6)
# Merge 825: ('A4&B4', 'G4&G4') -> A4&B4&G4&G4 (occurrences: 6)
# Merge 826: ('A4&C5', 'A4&A4&A4') -> A4&C5&A4&A4&A4 (occurrences: 6)
# Merge 827: ('A4&C5', 'A4&C5&A4') -> A4&C5&A4&C5&A4 (occurrences: 6)
# Merge 828: ('A4&C5&A4', 'C5&D5') -> A4&C5&A4&C5&D5 (occurrences: 6)
# Merge 829: ('A4&C5&C5', 'C5') -> A4&C5&C5&C5 (occurrences: 6)
# Merge 830: ('A4&C5&C5', 'C5&G4') -> A4&C5&C5&C5&G4 (occurrences: 6)
# Merge 831: ('A4&C5&C5&B4', 'G4') -> A4&C5&C5&B4&G4 (occurrences: 6)
# Merge 832: ('A4&G4', 'F4&D4') -> A4&G4&F4&D4 (occurrences: 6)
# Merge 833: ('A4&G4&A4', 'F4&F4') -> A4&G4&A4&F4&F4 (occurrences: 6)
# Merge 834: ('A4&G4&A4&B4', 'C5') -> A4&G4&A4&B4&C5 (occurrences: 6)
# Merge 835: ('A4&G4&A4&B4', 'G4') -> A4&G4&A4&B4&G4 (occurrences: 6)
# Merge 836: ('A4&G4&A4&G4', 'E4') -> A4&G4&A4&G4&E4 (occurrences: 6)
# Merge 837: ('A4&G4&F4&G4', 'E4') -> A4&G4&F4&G4&E4 (occurrences: 6)
# Merge 838: ('A4&G4&G4', 'C5&C5') -> A4&G4&G4&C5&C5 (occurrences: 6)
# Merge 839: ('A4&G4&G4', 'F4&A4') -> A4&G4&G4&F4&A4 (occurrences: 6)
# Merge 840: ('A4&G4&G4', 'F4&D4') -> A4&G4&G4&F4&D4 (occurrences: 6)
# Merge 841: ('A5', 'A5') -> A5&A5 (occurrences: 6)
# Merge 842: ('B4', 'C5&A4') -> B4&C5&A4 (occurrences: 6)
# Merge 843: ('B4', 'C5&B4&A4') -> B4&C5&B4&A4 (occurrences: 6)
# Merge 844: ('B4', 'C5&D5&E5&D5') -> B4&C5&D5&E5&D5 (occurrences: 6)
# Merge 845: ('B4', 'D5&E5&D5') -> B4&D5&E5&D5 (occurrences: 6)
# Merge 846: ('B4', 'G4&F4&G4') -> B4&G4&F4&G4 (occurrences: 6)
# Merge 847: ('B4&C5', 'A4&G4&A4') -> B4&C5&A4&G4&A4 (occurrences: 6)
# Merge 848: ('B5', 'C6') -> B5&C6 (occurrences: 6)
# Merge 849: ('C4', 'A3&C4&D4&D4') -> C4&A3&C4&D4&D4 (occurrences: 6)
# Merge 850: ('C4', 'E4') -> C4&E4 (occurrences: 6)
# Merge 851: ('C4', 'F4&E4&F4&G4') -> C4&F4&E4&F4&G4 (occurrences: 6)
# Merge 852: ('C4', 'F4&F4&G4') -> C4&F4&F4&G4 (occurrences: 6)
# Merge 853: ('C4&D4', 'E4&F4&D4') -> C4&D4&E4&F4&D4 (occurrences: 6)
# Merge 854: ('C4&D4&F4&F4', 'C4') -> C4&D4&F4&F4&C4 (occurrences: 6)
# Merge 855: ('C5', 'E5&F5&G5') -> C5&E5&F5&G5 (occurrences: 6)
# Merge 856: ('C5', 'G4&A4&C5&B4') -> C5&G4&A4&C5&B4 (occurrences: 6)
# Merge 857: ('C5&A4', 'C5&C5&C5') -> C5&A4&C5&C5&C5 (occurrences: 6)
# Merge 858: ('C5&B4', 'A4&G4&A4') -> C5&B4&A4&G4&A4 (occurrences: 6)
# Merge 859: ('C5&B4', 'C5&C5') -> C5&B4&C5&C5 (occurrences: 6)
# Merge 860: ('C5&B4&C5&B4', 'B4') -> C5&B4&C5&B4&B4 (occurrences: 6)
# Merge 861: ('C5&C5', 'A4&C5') -> C5&C5&A4&C5 (occurrences: 6)
# Merge 862: ('C5&C5', 'C5&D5&E5') -> C5&C5&C5&D5&E5 (occurrences: 6)
# Merge 863: ('C5&C5', 'G4&A4') -> C5&C5&G4&A4 (occurrences: 6)
# Merge 864: ('C5&D5&E5', 'G5') -> C5&D5&E5&G5 (occurrences: 6)
# Merge 865: ('D4', 'F4&D4&D4&C4') -> D4&F4&D4&D4&C4 (occurrences: 6)
# Merge 866: ('D4', 'F4&G4&A4&G4') -> D4&F4&G4&A4&G4 (occurrences: 6)
# Merge 867: ('D4', 'F4&G4&G4') -> D4&F4&G4&G4 (occurrences: 6)
# Merge 868: ('D4', 'G4&G4') -> D4&G4&G4 (occurrences: 6)
# Merge 869: ('D4&D4', 'C4&C4&D4') -> D4&D4&C4&C4&D4 (occurrences: 6)
# Merge 870: ('D4&D4&D4', 'F4&G4') -> D4&D4&D4&F4&G4 (occurrences: 6)
# Merge 871: ('D4&E4&D4', 'E4') -> D4&E4&D4&E4 (occurrences: 6)
# Merge 872: ('D5', 'C5&C5&C5') -> D5&C5&C5&C5 (occurrences: 6)
# Merge 873: ('D5&B4', 'C5') -> D5&B4&C5 (occurrences: 6)
# Merge 874: ('D5&C5&B4', 'A4') -> D5&C5&B4&A4 (occurrences: 6)
# Merge 875: ('D5&C5&B4', 'B4') -> D5&C5&B4&B4 (occurrences: 6)
# Merge 876: ('D5&C5&B4', 'C5&B4') -> D5&C5&B4&C5&B4 (occurrences: 6)
# Merge 877: ('D5&D5', 'C5&C5&B4') -> D5&D5&C5&C5&B4 (occurrences: 6)
# Merge 878: ('D5&F5', 'F5&F5') -> D5&F5&F5&F5 (occurrences: 6)
# Merge 879: ('E4', 'F4&E4&C4&D4') -> E4&F4&E4&C4&D4 (occurrences: 6)
# Merge 880: ('E4', 'F4&F4&E4') -> E4&F4&F4&E4 (occurrences: 6)
# Merge 881: ('E4&E4', 'E4&E4') -> E4&E4&E4&E4 (occurrences: 6)
# Merge 882: ('E4&F4&D4', 'C4') -> E4&F4&D4&C4 (occurrences: 6)
# Merge 883: ('E4&F4&E4', 'E4&D4') -> E4&F4&E4&E4&D4 (occurrences: 6)
# Merge 884: ('E4&F4&E4', 'G4') -> E4&F4&E4&G4 (occurrences: 6)
# Merge 885: ('E4&F4&G4', 'D4') -> E4&F4&G4&D4 (occurrences: 6)
# Merge 886: ('E5', 'C5&C5&B4') -> E5&C5&C5&B4 (occurrences: 6)
# Merge 887: ('E5', 'E5&D5&C5&B4') -> E5&E5&D5&C5&B4 (occurrences: 6)
# Merge 888: ('E5', 'G5&F5') -> E5&G5&F5 (occurrences: 6)
# Merge 889: ('E5&D5', 'D5&D5') -> E5&D5&D5&D5 (occurrences: 6)
# Merge 890: ('E5&E5', 'E5') -> E5&E5&E5 (occurrences: 6)
# Merge 891: ('E5&E5&D5', 'D5&D5') -> E5&E5&D5&D5&D5 (occurrences: 6)
# Merge 892: ('E5&G5', 'G5') -> E5&G5&G5 (occurrences: 6)
# Merge 893: ('F4&C4', 'A3') -> F4&C4&A3 (occurrences: 6)
# Merge 894: ('F4&D4', 'F4&C4') -> F4&D4&F4&C4 (occurrences: 6)
# Merge 895: ('F4&D4', 'F4&D4') -> F4&D4&F4&D4 (occurrences: 6)
# Merge 896: ('F4&E4', 'F4') -> F4&E4&F4 (occurrences: 6)
# Merge 897: ('F4&E4&D4', 'G4') -> F4&E4&D4&G4 (occurrences: 6)
# Merge 898: ('F4&E4&D4&D4', 'E4') -> F4&E4&D4&D4&E4 (occurrences: 6)
# Merge 899: ('F4&E4&D4&E4', 'D4') -> F4&E4&D4&E4&D4 (occurrences: 6)
# Merge 900: ('F4&F4&D4', 'C4&C4') -> F4&F4&D4&C4&C4 (occurrences: 6)
# Merge 901: ('F4&G4', 'D4') -> F4&G4&D4 (occurrences: 6)
# Merge 902: ('F4&G4', 'F4&F4&E4') -> F4&G4&F4&F4&E4 (occurrences: 6)
# Merge 903: ('F4&G4', 'G4&G4') -> F4&G4&G4&G4 (occurrences: 6)
# Merge 904: ('G4', 'A4&G4&A4&B4') -> G4&A4&G4&A4&B4 (occurrences: 6)
# Merge 905: ('G4', 'C5&B4') -> G4&C5&B4 (occurrences: 6)
# Merge 906: ('G4', 'F4&E4') -> G4&F4&E4 (occurrences: 6)
# Merge 907: ('G4&A4', 'F4&F4&D4') -> G4&A4&F4&F4&D4 (occurrences: 6)
# Merge 908: ('G4&A4&G4', 'F4&A4') -> G4&A4&G4&F4&A4 (occurrences: 6)
# Merge 909: ('G4&A4&G4', 'F4&E4') -> G4&A4&G4&F4&E4 (occurrences: 6)
# Merge 910: ('G4&E4', 'F4&E4') -> G4&E4&F4&E4 (occurrences: 6)
# Merge 911: ('G4&E4', 'G4&A4') -> G4&E4&G4&A4 (occurrences: 6)
# Merge 912: ('G4&G4', 'B4&C5&D5') -> G4&G4&B4&C5&D5 (occurrences: 6)
# Merge 913: ('G4&G4', 'F4') -> G4&G4&F4 (occurrences: 6)
# Merge 914: ('G4&G4', 'F4&A4') -> G4&G4&F4&A4 (occurrences: 6)
# Merge 915: ('G5&G5', 'G5') -> G5&G5&G5 (occurrences: 6)
# Merge 916: ('A4', 'D5') -> A4&D5 (occurrences: 5)
# Merge 917: ('A4&A4', 'C5&C5&B4') -> A4&A4&C5&C5&B4 (occurrences: 5)
# Merge 918: ('A4&A4', 'C5&C5&C5') -> A4&A4&C5&C5&C5 (occurrences: 5)
# Merge 919: ('A4&A4', 'D4') -> A4&A4&D4 (occurrences: 5)
# Merge 920: ('A4&A4', 'F4&A4') -> A4&A4&F4&A4 (occurrences: 5)
# Merge 921: ('A4&A4&A4&A4', 'B4') -> A4&A4&A4&A4&B4 (occurrences: 5)
# Merge 922: ('A4&A4&B4', 'A4&G4') -> A4&A4&B4&A4&G4 (occurrences: 5)
# Merge 923: ('A4&A4&B4', 'B4&B4') -> A4&A4&B4&B4&B4 (occurrences: 5)
# Merge 924: ('A4&A4&C5', 'G4') -> A4&A4&C5&G4 (occurrences: 5)
# Merge 925: ('A4&A4&C5', 'G4&A4') -> A4&A4&C5&G4&A4 (occurrences: 5)
# Merge 926: ('A4&B4', 'A4&A4&A4') -> A4&B4&A4&A4&A4 (occurrences: 5)
# Merge 927: ('A4&B4', 'B4&B4') -> A4&B4&B4&B4 (occurrences: 5)
# Merge 928: ('A4&B4', 'C5&C5&C5') -> A4&B4&C5&C5&C5 (occurrences: 5)
# Merge 929: ('A4&B4', 'G4&A4&B4') -> A4&B4&G4&A4&B4 (occurrences: 5)
# Merge 930: ('A4&B4&A4&G4', 'F4') -> A4&B4&A4&G4&F4 (occurrences: 5)
# Merge 931: ('A4&B4&C5', 'G4') -> A4&B4&C5&G4 (occurrences: 5)
# Merge 932: ('A4&B4&C5', 'G4&G4') -> A4&B4&C5&G4&G4 (occurrences: 5)
# Merge 933: ('A4&B4&G4', 'F4') -> A4&B4&G4&F4 (occurrences: 5)
# Merge 934: ('A4&C5', 'A4&C5&B4') -> A4&C5&A4&C5&B4 (occurrences: 5)
# Merge 935: ('A4&C5&B4', 'A4&A4') -> A4&C5&B4&A4&A4 (occurrences: 5)
# Merge 936: ('A4&C5&C5', 'D5&D5') -> A4&C5&C5&D5&D5 (occurrences: 5)
# Merge 937: ('A4&F4&G4', 'A4&C5') -> A4&F4&G4&A4&C5 (occurrences: 5)
# Merge 938: ('A4&F4&G4', 'D4') -> A4&F4&G4&D4 (occurrences: 5)
# Merge 939: ('A4&G4', 'C5&B4&C5') -> A4&G4&C5&B4&C5 (occurrences: 5)
# Merge 940: ('A4&G4', 'C5&C5&D5') -> A4&G4&C5&C5&D5 (occurrences: 5)
# Merge 941: ('A4&G4', 'F4&A4&C5') -> A4&G4&F4&A4&C5 (occurrences: 5)
# Merge 942: ('A4&G4&A4', 'D5&E5') -> A4&G4&A4&D5&E5 (occurrences: 5)
# Merge 943: ('A4&G4&A4&G4', 'B4') -> A4&G4&A4&G4&B4 (occurrences: 5)
# Merge 944: ('A4&G4&G4&G4', 'F4') -> A4&G4&G4&G4&F4 (occurrences: 5)
# Merge 945: ('B4', 'A4&G4&F4&G4') -> B4&A4&G4&F4&G4 (occurrences: 5)
# Merge 946: ('B4', 'C5&C5') -> B4&C5&C5 (occurrences: 5)
# Merge 947: ('B4&B4', 'C5&B4&B4') -> B4&B4&C5&B4&B4 (occurrences: 5)
# Merge 948: ('B4&C5', 'A4&G4&G4') -> B4&C5&A4&G4&G4 (occurrences: 5)
# Merge 949: ('C4', 'A3&C4&D4') -> C4&A3&C4&D4 (occurrences: 5)
# Merge 950: ('C4', 'E4&F4&G4') -> C4&E4&F4&G4 (occurrences: 5)
# Merge 951: ('C4', 'F4&E4&D4') -> C4&F4&E4&D4 (occurrences: 5)
# Merge 952: ('C4&D4', 'F4&E4&G4') -> C4&D4&F4&E4&G4 (occurrences: 5)
# Merge 953: ('C4&D4&D4', 'E4&E4') -> C4&D4&D4&E4&E4 (occurrences: 5)
# Merge 954: ('C4&F4&G4', 'A4&B4') -> C4&F4&G4&A4&B4 (occurrences: 5)
# Merge 955: ('C5', 'A4&B4&A4&G4') -> C5&A4&B4&A4&G4 (occurrences: 5)
# Merge 956: ('C5&A4&C5', 'A4&G4') -> C5&A4&C5&A4&G4 (occurrences: 5)
# Merge 957: ('C5&A4&C5', 'G4') -> C5&A4&C5&G4 (occurrences: 5)
# Merge 958: ('C5&B4', 'D5&E5') -> C5&B4&D5&E5 (occurrences: 5)
# Merge 959: ('C5&B4', 'D5&E5&D5') -> C5&B4&D5&E5&D5 (occurrences: 5)
# Merge 960: ('C5&B4', 'G4&G4') -> C5&B4&G4&G4 (occurrences: 5)
# Merge 961: ('C5&C5', 'A4&B4') -> C5&C5&A4&B4 (occurrences: 5)
# Merge 962: ('C5&C5', 'C5&D5&B4') -> C5&C5&C5&D5&B4 (occurrences: 5)
# Merge 963: ('C5&C5', 'E5&F5&G5') -> C5&C5&E5&F5&G5 (occurrences: 5)
# Merge 964: ('C5&C5', 'F4') -> C5&C5&F4 (occurrences: 5)
# Merge 965: ('C5&C5', 'G4') -> C5&C5&G4 (occurrences: 5)
# Merge 966: ('C5&D5', '') -> C5&D5& (occurrences: 5)
# Merge 967: ('C5&D5', 'A4&B4') -> C5&D5&A4&B4 (occurrences: 5)
# Merge 968: ('C5&D5', 'A4&G4&A4') -> C5&D5&A4&G4&A4 (occurrences: 5)
# Merge 969: ('C5&D5', 'G4&A4&C5') -> C5&D5&G4&A4&C5 (occurrences: 5)
# Merge 970: ('C5&D5&D5', 'C5&A4') -> C5&D5&D5&C5&A4 (occurrences: 5)
# Merge 971: ('C5&D5&E5&D5', '') -> C5&D5&E5&D5& (occurrences: 5)
# Merge 972: ('C5&D5&F5', 'F5&F5') -> C5&D5&F5&F5&F5 (occurrences: 5)
# Merge 973: ('D4', 'A4&G4') -> D4&A4&G4 (occurrences: 5)
# Merge 974: ('D4', 'E4&G4&A4') -> D4&E4&G4&A4 (occurrences: 5)
# Merge 975: ('D4', 'F4&F4&G4') -> D4&F4&F4&G4 (occurrences: 5)
# Merge 976: ('D4&C4', 'F4') -> D4&C4&F4 (occurrences: 5)
# Merge 977: ('D4&C4&D4', 'F4&E4') -> D4&C4&D4&F4&E4 (occurrences: 5)
# Merge 978: ('D4&D4', 'G4&F4&F4') -> D4&D4&G4&F4&F4 (occurrences: 5)
# Merge 979: ('D5', 'C5&') -> D5&C5& (occurrences: 5)
# Merge 980: ('D5', 'E5&F5&D5') -> D5&E5&F5&D5 (occurrences: 5)
# Merge 981: ('D5&B4', 'C5&C5&B4') -> D5&B4&C5&C5&B4 (occurrences: 5)
# Merge 982: ('D5&C5&B4', 'A4&G4') -> D5&C5&B4&A4&G4 (occurrences: 5)
# Merge 983: ('D5&C5&D5&F5', 'D5') -> D5&C5&D5&F5&D5 (occurrences: 5)
# Merge 984: ('D5&D5', 'E5&E5&D5') -> D5&D5&E5&E5&D5 (occurrences: 5)
# Merge 985: ('D5&D5', 'F5&E5&D5') -> D5&D5&F5&E5&D5 (occurrences: 5)
# Merge 986: ('D5&E5&D5', 'D5&B4') -> D5&E5&D5&D5&B4 (occurrences: 5)
# Merge 987: ('E4', 'F4&A4&C5&G4') -> E4&F4&A4&C5&G4 (occurrences: 5)
# Merge 988: ('E4', 'F4&E4&E4') -> E4&F4&E4&E4 (occurrences: 5)
# Merge 989: ('E4&D4', 'F4&E4&E4') -> E4&D4&F4&E4&E4 (occurrences: 5)
# Merge 990: ('E4&D4', 'F4&G4') -> E4&D4&F4&G4 (occurrences: 5)
# Merge 991: ('E4&E4', 'D4&E4&D4') -> E4&E4&D4&E4&D4 (occurrences: 5)
# Merge 992: ('E5&F5', 'F5') -> E5&F5&F5 (occurrences: 5)
# Merge 993: ('E5&F5&D5', 'C5') -> E5&F5&D5&C5 (occurrences: 5)
# Merge 994: ('E5&F5&G5', 'G5') -> E5&F5&G5&G5 (occurrences: 5)
# Merge 995: ('E5&G5', 'E5&D5') -> E5&G5&E5&D5 (occurrences: 5)
# Merge 996: ('F4', 'A4&A4&A4') -> F4&A4&A4&A4 (occurrences: 5)
# Merge 997: ('F4', 'C4&C4&D4') -> F4&C4&C4&D4 (occurrences: 5)
# Merge 998: ('F4', 'C5&C5&D5') -> F4&C5&C5&D5 (occurrences: 5)
# Merge 999: ('F4&C4&D4', 'F4&D4') -> F4&C4&D4&F4&D4 (occurrences: 5)
# Merge 1000: ('F4&D4', 'F4&A4&G4') -> F4&D4&F4&A4&G4 (occurrences: 5)
# Merge 1001: ('F4&D4&C4&D4', 'F4') -> F4&D4&C4&D4&F4 (occurrences: 5)
# Merge 1002: ('F4&D4&D4', 'F4&D4') -> F4&D4&D4&F4&D4 (occurrences: 5)
# Merge 1003: ('F4&E4', 'F4&A4&C5') -> F4&E4&F4&A4&C5 (occurrences: 5)
# Merge 1004: ('F4&E4&D4', 'C4&C4') -> F4&E4&D4&C4&C4 (occurrences: 5)
# Merge 1005: ('F4&E4&E4', 'G4&G4') -> F4&E4&E4&G4&G4 (occurrences: 5)
# Merge 1006: ('F4&F4', 'A4&G4') -> F4&F4&A4&G4 (occurrences: 5)
# Merge 1007: ('F4&F4', 'C4&D4') -> F4&F4&C4&D4 (occurrences: 5)
# Merge 1008: ('F4&F4&D4', 'G4') -> F4&F4&D4&G4 (occurrences: 5)
# Merge 1009: ('F4&F4&E4', 'E4&D4') -> F4&F4&E4&E4&D4 (occurrences: 5)
# Merge 1010: ('F4&F4&E4&D4', 'C4') -> F4&F4&E4&D4&C4 (occurrences: 5)
# Merge 1011: ('F4&G4', 'B4') -> F4&G4&B4 (occurrences: 5)
# Merge 1012: ('F4&G4', 'G4&G4&G4') -> F4&G4&G4&G4&G4 (occurrences: 5)
# Merge 1013: ('F4&G4&G4', 'D5&D5') -> F4&G4&G4&D5&D5 (occurrences: 5)
# Merge 1014: ('F5', 'G5&F5') -> F5&G5&F5 (occurrences: 5)
# Merge 1015: ('G4', 'C5&C5&B4') -> G4&C5&C5&B4 (occurrences: 5)
# Merge 1016: ('G4', 'F4&F4&E4&D4') -> G4&F4&F4&E4&D4 (occurrences: 5)
# Merge 1017: ('G4&A4', 'E4&E4') -> G4&A4&E4&E4 (occurrences: 5)
# Merge 1018: ('G4&A4', 'F4&A4') -> G4&A4&F4&A4 (occurrences: 5)
# Merge 1019: ('G4&A4', 'F4&E4') -> G4&A4&F4&E4 (occurrences: 5)
# Merge 1020: ('G4&E4', 'G4') -> G4&E4&G4 (occurrences: 5)
# Merge 1021: ('G4&F4&G4', 'G4&G4') -> G4&F4&G4&G4&G4 (occurrences: 5)
# Merge 1022: ('G4&G4', 'A4&B4') -> G4&G4&A4&B4 (occurrences: 5)
# Merge 1023: ('G5', 'D5&F5') -> G5&D5&F5 (occurrences: 5)
# Merge 1024: ('G5&F5&E5&D5', 'C5') -> G5&F5&E5&D5&C5 (occurrences: 5)
# Total merges: 1024
# Time taken: 8.07 seconds

# %% [markdown]
# Once we obtained the raw vocabulary, we process it so its format is compatible with the software for plotting a Zipf's Curve.

# %%
# !awk 'NF > 1' "../results/test/BPE_5-5_vocab.txt" | sort -k2,2nr | nl > "../results/test/BPE_5-5_vocab_sorted.txt"

# %% [markdown]
# Then we can see how it looks. The first column is the rank, the second column is the word and the third column is the number of occurrences of that word.

# %%
with open("../results/test/BPE_5-5_vocab_sorted.txt", "r") as f:
    vocab = f.readlines()
for line in vocab[:10]:
    print(line.strip())
# Out:
# 1	A4&G4&F4&G4 1213
# 2	A4&G4&A4&G4 742
# 3	C5&D5&C5&B4 703
# 4	A4&G4&G4 673
# 5	F4&E4&F4&G4 673
# 6	A4&G4&A4 638
# 7	A4&G4 618
# 8	C5&C5&C5&C5 601
# 9	A4&B4&C5&B4 575
# 10	A4&G4&A4&B4 564

# %% [markdown]
# An the original GT encoded for this vocabulary looks like this...

# %%
with open("../results/test/BPE_5-5_encoded.txt", "r") as f:
    vocab = f.readlines()
for line in vocab[:10]:
    print(line.strip())
# Out:
# CH-E-611_001r-1 G4&G4&F4&F4&G4 C4&D4&F4&G4 A4&G4&F4&G4&G4
# CH-E-611_001r-2 C5&C5&C5&C5 C5&C5&C5&C5 C5&B4&A4
# CH-E-611_001r-3 D4&D4&C4&F4&G4 F4&G4&A4&A4 A4&C5&B4 C5&D5&C5&A4&B4 A4&G4&F4&G4 A4&B4&A4 A4&G4&A4&G4 G4&G4 E4 G4&A4&G4&F4&G4 F4&D4&C4&D4 G4&E4 F4&E4&D4&D4&A4 A4&G4&F4&G4&A4
# CH-E-611_001r-4 C4&D4 F4&F4&D4 E4 F4&E4&D4&C4&D4 F4&E4&D4&D4 F4&E4&E4&F4&G4 A4&B4&A4&G4 A4&G4&G4 F4&E4&D4&E4&E4 C4 F4&E4&E4 G4&A4&G4&F4&G4 E4&E4&G4&A4
# CH-E-611_001r-5 E4&F4&G4 G4&A4&C5&B4 C5&B4&A4&G4 E4&F4&G4 G4&G4&G4&G4 C5&C5 C5&D5&C5&B4 A4&C5 A4&C5&B4&C5&B4 A4&G4&A4&C5&B4 G4&G4&G4&G4 G4&A4&F4&E4&D4 G4 F4&A4 C5&B4&A4&B4 G4&G4 C5&C5&B4&C5 A4&G4&A4
# CH-E-611_001r-6 F4&E4&D4&C4&D4 F4&E4&D4&C4&D4 E4&F4&G4 F4&G4&A4&G4 F4&E4 E4&E4&D4 G4&G4 A4&A4&C5 A4&A4&C5 A4&A4&A4 A4&G4&F4&G4&G4 F4&E4&E4&E4 G4&A4&A4 C5&A4 A4&G4&G4&F4&G4 F4&F4&E4&F4&G4 G4 F4&D4&C4 C4&C4&D4 E4&F4&G4&G4 F4&E4&E4 A4&G4&A4&C5&G4
# CH-E-611_001r-7 C4&D4 E4&F4&E4&D4 G4&F4&G4 F4&E4&D4&E4 E4&F4&E4&D4&E4 C4&F4&G4 E4&D4 F4&E4&E4&D4 E4 G4&A4&C5 A4&A4&G4&F4&G4 G4&A4&G4 F4&E4&F4&G4 F4&E4&F4&G4 F4&F4&F4&G4 A4&G4&F4&G4 G4&A4&G4 F4&E4&D4 F4&F4&E4&D4&E4 G4&A4&C5 A4&A4&A4&A4 C5&G4 F4&E4&E4&F4&G4 E4&F4&E4&D4&D4 E4&F4&G4&F4&G4 F4&E4&D4&E4 F4&E4&E4 A4&G4&A4&C5 G4&E4&F4&E4&D4
# CH-E-611_001r-8 F4&E4&D4 F4&D4&D4 C4&D4&D4&E4&E4 G4&G4&A4 A4&G4&A4&C5&B4 G4&F4&G4 F4&D4 E4&E4&D4 A4&C5&A4&G4 A4&G4&F4&G4 A4&A4 F4&E4&D4 F4&E4&E4 F4&E4&F4&G4&G4 F4&E4&D4&C4&D4 C4&D4&D4 G4&A4&G4&G4 F4&D4&E4&F4&G4 F4&G4&A4&G4 F4&E4&E4 A4&G4&A4&C5&G4
# CH-E-611_001r-9 D5&D5 C5&D5&C5&C5&B4 D5&D5&F5 D5&C5&D5&D5 F5 D5&F5&D5 C5&D5&C5&D5&D5 F5 E5&F5&G5 G5&A5 D5&D5&F5 E5&E5 G5&F5 E5&F5&E5&D5 D5&F5 E5&F5&E5&D5 D5&D5 C5&D5&C5&C5&D5 A4&G4&F4&G4&G4 A4&C5&A4&B4 A4&A4&A4&G4 D5&C5&D5 E5&F5 C5&D5&E5&D5 C5&D5&C5&B4&B4 D5&C5&D5&C5&B4 B4 D5&C5&D5&E5 E5&F5 B4 D5&C5 E5&G5&F5 E5&F5&E5&D5 D5&F5 E5&F5&E5&D5 D5&E5&F5&E5&D5 D5&E5&D5 C5&C5&D5&E5&D5 E5&F5&E5&D5 C5&C5&C5 A4&B4&C5&B4 A4&G4&A4&A4&G4 D5&D5&C5&D5&E5 C5&C5&D5&E5&D5 E5&D5 E5&F5 E5&C5&D5&D5 E5&D5&E5 C5&D5&C5&C5&A4 C5&D5&E5&D5 D5&C5&C5 E5&D5 B4&C5&A4&G4 C5&A4&G4&A4&B4 A4&G4&F4&G4&A4 C5&C5&B4 D5 C5&C5&B4&A4 C5&D5&F5 E5&F5&E5&D5 E5&D5&D5&D5 C5&D5&C5&C5&D5 A4&G4 C5&C5&A4&C5&B4 C5&E5&D5 B4&C5&A4&G4 C5&A4&A4&G4
# CH-E-611_001v-1 D5&E5&F5&E5&D5 C5&D5&C5&C5&B4 C5&C5&D5 C5&C5&D5 C5&C5&D5 C5&D5&D5&D5&D5 E5&F5&E5&E5&D5 C5&D5&C5&C5&B4 C5&D5&C5&D5&D5 E5&D5 D5&E5&D5&E5&D5 C5&D5&C5&C5&D5 E5&D5 E5&F5&E5&D5 C5&D5&E5&D5 E5&D5&C5&B4 C5&B4 D5&E5&F5&E5&D5 E5&D5
